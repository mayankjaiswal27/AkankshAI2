# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=25, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=50)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

data_3 = pd.read_csv("data_3.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using the concatenated output of the parallel AIs and the third dataset
model_combined.fit(combined_output, y_data_3_encoded[:min_rows], epochs=100, validation_split=0.2)

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/25
# 1/1 [==============================] - 2s 2s/step - loss: 1.1230 - accuracy: 0.2500 - val_loss: 0.4138 - val_accuracy: 1.0000
# Epoch 2/25
# 1/1 [==============================] - 0s 336ms/step - loss: 0.9530 - accuracy: 0.2500 - val_loss: 0.5124 - val_accuracy: 1.0000
# Epoch 3/25
# 1/1 [==============================] - 0s 205ms/step - loss: 0.8146 - accuracy: 0.2500 - val_loss: 0.6195 - val_accuracy: 1.0000
# Epoch 4/25
# 1/1 [==============================] - 0s 135ms/step - loss: 0.7051 - accuracy: 0.5000 - val_loss: 0.7327 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1/1 [==============================] - 0s 299ms/step - loss: 0.6230 - accuracy: 0.7500 - val_loss: 0.8497 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1/1 [==============================] - 0s 362ms/step - loss: 0.5622 - accuracy: 0.7500 - val_loss: 0.9691 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5203 - accuracy: 0.7500 - val_loss: 1.0804 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 1/1 [==============================] - 0s 108ms/step - loss: 0.4888 - accuracy: 0.7500 - val_loss: 1.1798 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 1/1 [==============================] - 0s 106ms/step - loss: 0.4630 - accuracy: 0.7500 - val_loss: 1.2681 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 1/1 [==============================] - 0s 105ms/step - loss: 0.4394 - accuracy: 0.7500 - val_loss: 1.3411 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4166 - accuracy: 0.7500 - val_loss: 1.3980 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3932 - accuracy: 0.7500 - val_loss: 1.4399 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3705 - accuracy: 0.7500 - val_loss: 1.4676 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3471 - accuracy: 0.7500 - val_loss: 1.4820 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3246 - accuracy: 0.7500 - val_loss: 1.4855 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3024 - accuracy: 0.7500 - val_loss: 1.4789 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2810 - accuracy: 0.7500 - val_loss: 1.4632 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 1/1 [==============================] - 0s 82ms/step - loss: 0.2608 - accuracy: 1.0000 - val_loss: 1.4437 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 1/1 [==============================] - 0s 89ms/step - loss: 0.2420 - accuracy: 1.0000 - val_loss: 1.4231 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 1/1 [==============================] - 0s 228ms/step - loss: 0.2243 - accuracy: 1.0000 - val_loss: 1.4036 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 1/1 [==============================] - 0s 262ms/step - loss: 0.2077 - accuracy: 1.0000 - val_loss: 1.3858 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1920 - accuracy: 1.0000 - val_loss: 1.3709 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1774 - accuracy: 1.0000 - val_loss: 1.3594 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 1/1 [==============================] - 0s 105ms/step - loss: 0.1640 - accuracy: 1.0000 - val_loss: 1.3532 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 1/1 [==============================] - 0s 126ms/step - loss: 0.1517 - accuracy: 1.0000 - val_loss: 1.3528 - val_accuracy: 0.0000e+00
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 2/2 [==============================] - 1s 6ms/step - loss: 1.0720 - accuracy: 0.3818
# Epoch 2/50
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0388 - accuracy: 0.5091
# Epoch 3/50
# 2/2 [==============================] - 0s 25ms/step - loss: 1.0147 - accuracy: 0.5273
# Epoch 4/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9915 - accuracy: 0.5636
# Epoch 5/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9726 - accuracy: 0.5091
# Epoch 6/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9523 - accuracy: 0.5091
# Epoch 7/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9350 - accuracy: 0.5091
# Epoch 8/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9172 - accuracy: 0.5091
# Epoch 9/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.8983 - accuracy: 0.5636
# Epoch 10/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8799 - accuracy: 0.5455
# Epoch 11/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8604 - accuracy: 0.5818
# Epoch 12/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8406 - accuracy: 0.6182
# Epoch 13/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8192 - accuracy: 0.6182
# Epoch 14/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.7983 - accuracy: 0.6182
# Epoch 15/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7792 - accuracy: 0.6545
# Epoch 16/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7609 - accuracy: 0.7455
# Epoch 17/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7415 - accuracy: 0.7455
# Epoch 18/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7235 - accuracy: 0.7818
# Epoch 19/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.7049 - accuracy: 0.7818
# Epoch 20/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6872 - accuracy: 0.7818
# Epoch 21/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6685 - accuracy: 0.7818
# Epoch 22/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6508 - accuracy: 0.7818
# Epoch 23/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6347 - accuracy: 0.7818
# Epoch 24/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6187 - accuracy: 0.7818
# Epoch 25/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6039 - accuracy: 0.7818
# Epoch 26/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5896 - accuracy: 0.7636
# Epoch 27/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5749 - accuracy: 0.7818
# Epoch 28/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5605 - accuracy: 0.7818
# Epoch 29/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5488 - accuracy: 0.7818
# Epoch 30/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5353 - accuracy: 0.8000
# Epoch 31/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5223 - accuracy: 0.8182
# Epoch 32/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5109 - accuracy: 0.8364
# Epoch 33/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5004 - accuracy: 0.8182
# Epoch 34/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4887 - accuracy: 0.8364
# Epoch 35/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4784 - accuracy: 0.8364
# Epoch 36/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4681 - accuracy: 0.8545
# Epoch 37/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4581 - accuracy: 0.8545
# Epoch 38/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4502 - accuracy: 0.8545
# Epoch 39/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4396 - accuracy: 0.8727
# Epoch 40/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4307 - accuracy: 0.8727
# Epoch 41/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4223 - accuracy: 0.8727
# Epoch 42/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4147 - accuracy: 0.8727
# Epoch 43/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4068 - accuracy: 0.8727
# Epoch 44/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3975 - accuracy: 0.8727
# Epoch 45/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3904 - accuracy: 0.8727
# Epoch 46/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3833 - accuracy: 0.8727
# Epoch 47/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3754 - accuracy: 0.8727
# Epoch 48/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3685 - accuracy: 0.8727
# Epoch 49/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3618 - accuracy: 0.8727
# Epoch 50/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3550 - accuracy: 0.8727
# Epoch 1/50
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 1s 3ms/step - loss: 1.3891 - accuracy: 0.2750
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3596 - accuracy: 0.4900
# Epoch 3/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3353 - accuracy: 0.4000
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3168 - accuracy: 0.5200
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2951 - accuracy: 0.6300
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2723 - accuracy: 0.7250
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2485 - accuracy: 0.7000
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2209 - accuracy: 0.7850
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1919 - accuracy: 0.9150
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1587 - accuracy: 0.9250
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1277 - accuracy: 0.9250
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0880 - accuracy: 0.9850
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0541 - accuracy: 0.9800
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0128 - accuracy: 0.9250
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9690 - accuracy: 0.9150
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9244 - accuracy: 0.9550
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8802 - accuracy: 0.9850
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8393 - accuracy: 0.9850
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7932 - accuracy: 0.9850
# Epoch 20/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7481 - accuracy: 0.9850
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7065 - accuracy: 0.9850
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6657 - accuracy: 0.9850
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6232 - accuracy: 0.9850
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5901 - accuracy: 0.9850
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5472 - accuracy: 0.9900
# Epoch 26/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5181 - accuracy: 0.9800
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.9900
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.9850
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4240 - accuracy: 0.9850
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.9900
# Epoch 31/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3681 - accuracy: 0.9900
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3435 - accuracy: 0.9900
# Epoch 33/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.9900
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3004 - accuracy: 0.9900
# Epoch 35/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.9900
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.9900
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.9900
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2355 - accuracy: 0.9900
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2184 - accuracy: 0.9900
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2090 - accuracy: 0.9850
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1971 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.9900
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1752 - accuracy: 0.9900
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1668 - accuracy: 0.9900
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9900
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1499 - accuracy: 0.9900
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1428 - accuracy: 0.9900
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1361 - accuracy: 0.9900
# Epoch 49/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9900
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1244 - accuracy: 0.9900
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 0s 6ms/step
# 7/7 [==============================] - 0s 2ms/step
# Epoch 1/100
# 2/2 [==============================] - 1s 224ms/step - loss: 1.3784 - accuracy: 0.3409 - val_loss: 1.4392 - val_accuracy: 0.0909
# Epoch 2/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.3569 - accuracy: 0.4091 - val_loss: 1.4473 - val_accuracy: 0.0909
# Epoch 3/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.3444 - accuracy: 0.4091 - val_loss: 1.4579 - val_accuracy: 0.0909
# Epoch 4/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.3342 - accuracy: 0.4091 - val_loss: 1.4670 - val_accuracy: 0.0909
# Epoch 5/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.3230 - accuracy: 0.4091 - val_loss: 1.4755 - val_accuracy: 0.0909
# Epoch 6/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.3153 - accuracy: 0.4091 - val_loss: 1.4866 - val_accuracy: 0.0909
# Epoch 7/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.3087 - accuracy: 0.4091 - val_loss: 1.5013 - val_accuracy: 0.0909
# Epoch 8/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.3034 - accuracy: 0.4091 - val_loss: 1.5204 - val_accuracy: 0.0909
# Epoch 9/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2987 - accuracy: 0.4091 - val_loss: 1.5414 - val_accuracy: 0.0909
# Epoch 10/100
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2935 - accuracy: 0.4091 - val_loss: 1.5603 - val_accuracy: 0.0909
# Epoch 11/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2906 - accuracy: 0.4091 - val_loss: 1.5772 - val_accuracy: 0.0909
# Epoch 12/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2874 - accuracy: 0.4091 - val_loss: 1.5910 - val_accuracy: 0.0909
# Epoch 13/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2854 - accuracy: 0.4091 - val_loss: 1.6033 - val_accuracy: 0.0909
# Epoch 14/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2832 - accuracy: 0.4091 - val_loss: 1.6120 - val_accuracy: 0.0909
# Epoch 15/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2820 - accuracy: 0.4091 - val_loss: 1.6167 - val_accuracy: 0.0909
# Epoch 16/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2795 - accuracy: 0.4091 - val_loss: 1.6152 - val_accuracy: 0.0909
# Epoch 17/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2773 - accuracy: 0.4091 - val_loss: 1.6125 - val_accuracy: 0.0909
# Epoch 18/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2754 - accuracy: 0.4091 - val_loss: 1.6095 - val_accuracy: 0.0909
# Epoch 19/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2734 - accuracy: 0.4091 - val_loss: 1.6076 - val_accuracy: 0.0909
# Epoch 20/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2714 - accuracy: 0.4091 - val_loss: 1.6060 - val_accuracy: 0.0909
# Epoch 21/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.2704 - accuracy: 0.4091 - val_loss: 1.6027 - val_accuracy: 0.0909
# Epoch 22/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1.2695 - accuracy: 0.4091 - val_loss: 1.6025 - val_accuracy: 0.0909
# Epoch 23/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2673 - accuracy: 0.4091 - val_loss: 1.6006 - val_accuracy: 0.0909
# Epoch 24/100
# 2/2 [==============================] - 0s 105ms/step - loss: 1.2655 - accuracy: 0.4091 - val_loss: 1.5986 - val_accuracy: 0.0909
# Epoch 25/100
# 2/2 [==============================] - 0s 45ms/step - loss: 1.2642 - accuracy: 0.4091 - val_loss: 1.5960 - val_accuracy: 0.0909
# Epoch 26/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2620 - accuracy: 0.4091 - val_loss: 1.5907 - val_accuracy: 0.0909
# Epoch 27/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2604 - accuracy: 0.4091 - val_loss: 1.5827 - val_accuracy: 0.0909
# Epoch 28/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2595 - accuracy: 0.4091 - val_loss: 1.5770 - val_accuracy: 0.0909
# Epoch 29/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2578 - accuracy: 0.4091 - val_loss: 1.5722 - val_accuracy: 0.0909
# Epoch 30/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2580 - accuracy: 0.4091 - val_loss: 1.5696 - val_accuracy: 0.0909
# Epoch 31/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2563 - accuracy: 0.4091 - val_loss: 1.5659 - val_accuracy: 0.0909
# Epoch 32/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2559 - accuracy: 0.4091 - val_loss: 1.5655 - val_accuracy: 0.0909
# Epoch 33/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2556 - accuracy: 0.4091 - val_loss: 1.5649 - val_accuracy: 0.0909
# Epoch 34/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2539 - accuracy: 0.4091 - val_loss: 1.5636 - val_accuracy: 0.0909
# Epoch 35/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2534 - accuracy: 0.4091 - val_loss: 1.5660 - val_accuracy: 0.0909
# Epoch 36/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2524 - accuracy: 0.4318 - val_loss: 1.5694 - val_accuracy: 0.0909
# Epoch 37/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2526 - accuracy: 0.4318 - val_loss: 1.5748 - val_accuracy: 0.0909
# Epoch 38/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2510 - accuracy: 0.4318 - val_loss: 1.5766 - val_accuracy: 0.0909
# Epoch 39/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2500 - accuracy: 0.4318 - val_loss: 1.5773 - val_accuracy: 0.0909
# Epoch 40/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2479 - accuracy: 0.4318 - val_loss: 1.5817 - val_accuracy: 0.0909
# Epoch 41/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2465 - accuracy: 0.4318 - val_loss: 1.5897 - val_accuracy: 0.0909
# Epoch 42/100
# 2/2 [==============================] - 0s 37ms/step - loss: 1.2460 - accuracy: 0.4318 - val_loss: 1.5992 - val_accuracy: 0.0909
# Epoch 43/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2435 - accuracy: 0.4091 - val_loss: 1.6086 - val_accuracy: 0.0909
# Epoch 44/100
# 2/2 [==============================] - 0s 37ms/step - loss: 1.2425 - accuracy: 0.4091 - val_loss: 1.6155 - val_accuracy: 0.0909
# Epoch 45/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2418 - accuracy: 0.4318 - val_loss: 1.6226 - val_accuracy: 0.0909
# Epoch 46/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2402 - accuracy: 0.4318 - val_loss: 1.6285 - val_accuracy: 0.0909
# Epoch 47/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2393 - accuracy: 0.4318 - val_loss: 1.6369 - val_accuracy: 0.0909
# Epoch 48/100
# 2/2 [==============================] - 0s 36ms/step - loss: 1.2373 - accuracy: 0.4318 - val_loss: 1.6449 - val_accuracy: 0.0909
# Epoch 49/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2357 - accuracy: 0.4318 - val_loss: 1.6557 - val_accuracy: 0.0909
# Epoch 50/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2349 - accuracy: 0.4318 - val_loss: 1.6695 - val_accuracy: 0.0909
# Epoch 51/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2333 - accuracy: 0.4318 - val_loss: 1.6815 - val_accuracy: 0.0909
# Epoch 52/100
# 2/2 [==============================] - 0s 97ms/step - loss: 1.2327 - accuracy: 0.4091 - val_loss: 1.6919 - val_accuracy: 0.0909
# Epoch 53/100
# 2/2 [==============================] - 0s 37ms/step - loss: 1.2318 - accuracy: 0.4318 - val_loss: 1.6998 - val_accuracy: 0.0909
# Epoch 54/100
# 2/2 [==============================] - 0s 61ms/step - loss: 1.2300 - accuracy: 0.4318 - val_loss: 1.7000 - val_accuracy: 0.0909
# Epoch 55/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2293 - accuracy: 0.4318 - val_loss: 1.7003 - val_accuracy: 0.0909
# Epoch 56/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2280 - accuracy: 0.4318 - val_loss: 1.7041 - val_accuracy: 0.0909
# Epoch 57/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2272 - accuracy: 0.4318 - val_loss: 1.7095 - val_accuracy: 0.0909
# Epoch 58/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2267 - accuracy: 0.4318 - val_loss: 1.7183 - val_accuracy: 0.0909
# Epoch 59/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.2258 - accuracy: 0.4318 - val_loss: 1.7293 - val_accuracy: 0.0909
# Epoch 60/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2248 - accuracy: 0.4318 - val_loss: 1.7354 - val_accuracy: 0.0909
# Epoch 61/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.2248 - accuracy: 0.4318 - val_loss: 1.7348 - val_accuracy: 0.0909
# Epoch 62/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1.2229 - accuracy: 0.4318 - val_loss: 1.7272 - val_accuracy: 0.0909
# Epoch 63/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.2223 - accuracy: 0.4318 - val_loss: 1.7215 - val_accuracy: 0.0909
# Epoch 64/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2210 - accuracy: 0.4318 - val_loss: 1.7156 - val_accuracy: 0.0909
# Epoch 65/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2217 - accuracy: 0.4318 - val_loss: 1.7146 - val_accuracy: 0.0909
# Epoch 66/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2197 - accuracy: 0.4318 - val_loss: 1.7247 - val_accuracy: 0.0909
# Epoch 67/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2183 - accuracy: 0.4318 - val_loss: 1.7405 - val_accuracy: 0.0909
# Epoch 68/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2172 - accuracy: 0.4318 - val_loss: 1.7495 - val_accuracy: 0.0909
# Epoch 69/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1.2160 - accuracy: 0.4318 - val_loss: 1.7568 - val_accuracy: 0.0909
# Epoch 70/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2163 - accuracy: 0.4318 - val_loss: 1.7739 - val_accuracy: 0.0909
# Epoch 71/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2149 - accuracy: 0.4318 - val_loss: 1.7861 - val_accuracy: 0.0909
# Epoch 72/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2127 - accuracy: 0.4318 - val_loss: 1.7901 - val_accuracy: 0.0909
# Epoch 73/100
# 2/2 [==============================] - 0s 63ms/step - loss: 1.2112 - accuracy: 0.4318 - val_loss: 1.7869 - val_accuracy: 0.0909
# Epoch 74/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1.2095 - accuracy: 0.4318 - val_loss: 1.7821 - val_accuracy: 0.0909
# Epoch 75/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2082 - accuracy: 0.4318 - val_loss: 1.7741 - val_accuracy: 0.0909
# Epoch 76/100
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2077 - accuracy: 0.4318 - val_loss: 1.7629 - val_accuracy: 0.0909
# Epoch 77/100
# 2/2 [==============================] - 0s 144ms/step - loss: 1.2071 - accuracy: 0.4318 - val_loss: 1.7565 - val_accuracy: 0.0909
# Epoch 78/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2069 - accuracy: 0.4318 - val_loss: 1.7551 - val_accuracy: 0.0909
# Epoch 79/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.2065 - accuracy: 0.4318 - val_loss: 1.7586 - val_accuracy: 0.0909
# Epoch 80/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.2048 - accuracy: 0.4318 - val_loss: 1.7669 - val_accuracy: 0.0909
# Epoch 81/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2026 - accuracy: 0.4318 - val_loss: 1.7817 - val_accuracy: 0.0909
# Epoch 82/100
# 2/2 [==============================] - 0s 43ms/step - loss: 1.2020 - accuracy: 0.4318 - val_loss: 1.7974 - val_accuracy: 0.0909
# Epoch 83/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.1997 - accuracy: 0.4545 - val_loss: 1.8079 - val_accuracy: 0.0909
# Epoch 84/100
# 2/2 [==============================] - 0s 53ms/step - loss: 1.1987 - accuracy: 0.4545 - val_loss: 1.8166 - val_accuracy: 0.0909
# Epoch 85/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.1976 - accuracy: 0.4545 - val_loss: 1.8186 - val_accuracy: 0.0909
# Epoch 86/100
# 2/2 [==============================] - 0s 42ms/step - loss: 1.1962 - accuracy: 0.4545 - val_loss: 1.8162 - val_accuracy: 0.0909
# Epoch 87/100
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1968 - accuracy: 0.4318 - val_loss: 1.8125 - val_accuracy: 0.0909
# Epoch 88/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.1945 - accuracy: 0.4545 - val_loss: 1.8177 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 2/2 [==============================] - 0s 39ms/step - loss: 1.1925 - accuracy: 0.4318 - val_loss: 1.8352 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.1927 - accuracy: 0.4318 - val_loss: 1.8579 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 2/2 [==============================] - 0s 41ms/step - loss: 1.1914 - accuracy: 0.4318 - val_loss: 1.8724 - val_accuracy: 0.0909
# Epoch 92/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1.1904 - accuracy: 0.4318 - val_loss: 1.8787 - val_accuracy: 0.0909
# Epoch 93/100
# 2/2 [==============================] - 0s 51ms/step - loss: 1.1887 - accuracy: 0.4773 - val_loss: 1.8865 - val_accuracy: 0.0909
# Epoch 94/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.1883 - accuracy: 0.4545 - val_loss: 1.8900 - val_accuracy: 0.0909
# Epoch 95/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1.1862 - accuracy: 0.4545 - val_loss: 1.8831 - val_accuracy: 0.0909
# Epoch 96/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1.1848 - accuracy: 0.4318 - val_loss: 1.8798 - val_accuracy: 0.0909
# Epoch 97/100
# 2/2 [==============================] - 0s 66ms/step - loss: 1.1831 - accuracy: 0.4318 - val_loss: 1.8782 - val_accuracy: 0.0909
# Epoch 98/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1814 - accuracy: 0.4318 - val_loss: 1.8752 - val_accuracy: 0.0909
# Epoch 99/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1802 - accuracy: 0.4318 - val_loss: 1.8710 - val_accuracy: 0.0909
# Epoch 100/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.1792 - accuracy: 0.4318 - val_loss: 1.8620 - val_accuracy: 0.0909
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic)
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1)
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2)
print("Predicted Labels - Combined AI:", predicted_labels_combined)
# Out:
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 100ms/step
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x164f428e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 121ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x164efc540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 209ms/step
# Predicted Labels - Generic AI: ['Engineering']
# Predicted Labels - Parallel AI 1: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Parallel AI 2: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Combined AI: ['Civil Engineering']
