# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=25, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=50)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

data_3 = pd.read_csv("data_3.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using the concatenated output of the parallel AIs and the third dataset
model_combined.fit(combined_output, y_data_3_encoded[:min_rows], epochs=100, validation_split=0.2)

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/25
# 1/1 [==============================] - 7s 7s/step - loss: 0.6500 - accuracy: 0.7500 - val_loss: 0.7414 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1/1 [==============================] - 0s 145ms/step - loss: 0.5640 - accuracy: 0.7500 - val_loss: 0.8423 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1/1 [==============================] - 0s 301ms/step - loss: 0.5005 - accuracy: 0.7500 - val_loss: 0.9243 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1/1 [==============================] - 0s 101ms/step - loss: 0.4499 - accuracy: 0.7500 - val_loss: 0.9841 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1/1 [==============================] - 0s 128ms/step - loss: 0.4048 - accuracy: 0.7500 - val_loss: 1.0280 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1/1 [==============================] - 0s 108ms/step - loss: 0.3650 - accuracy: 0.7500 - val_loss: 1.0602 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1/1 [==============================] - 0s 120ms/step - loss: 0.3293 - accuracy: 0.7500 - val_loss: 1.0749 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 1/1 [==============================] - 0s 231ms/step - loss: 0.2967 - accuracy: 1.0000 - val_loss: 1.0844 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 1/1 [==============================] - 0s 99ms/step - loss: 0.2685 - accuracy: 1.0000 - val_loss: 1.0953 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 1/1 [==============================] - 0s 109ms/step - loss: 0.2442 - accuracy: 1.0000 - val_loss: 1.1103 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 1/1 [==============================] - 0s 102ms/step - loss: 0.2231 - accuracy: 1.0000 - val_loss: 1.1326 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 1/1 [==============================] - 0s 147ms/step - loss: 0.2051 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 1/1 [==============================] - 0s 137ms/step - loss: 0.1875 - accuracy: 1.0000 - val_loss: 1.1982 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1706 - accuracy: 1.0000 - val_loss: 1.2475 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 1/1 [==============================] - 0s 229ms/step - loss: 0.1550 - accuracy: 1.0000 - val_loss: 1.3088 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 1/1 [==============================] - 0s 242ms/step - loss: 0.1401 - accuracy: 1.0000 - val_loss: 1.3750 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 1/1 [==============================] - 0s 203ms/step - loss: 0.1261 - accuracy: 1.0000 - val_loss: 1.4457 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 1/1 [==============================] - 0s 255ms/step - loss: 0.1134 - accuracy: 1.0000 - val_loss: 1.5168 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 1/1 [==============================] - 0s 170ms/step - loss: 0.1020 - accuracy: 1.0000 - val_loss: 1.5875 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0918 - accuracy: 1.0000 - val_loss: 1.6558 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 1.7233 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 1/1 [==============================] - 0s 192ms/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 1.7868 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 1.8450 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 1.8983 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 1.9462 - val_accuracy: 0.0000e+00
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 2/2 [==============================] - 3s 8ms/step - loss: 1.1550 - accuracy: 0.1818
# Epoch 2/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.1121 - accuracy: 0.3091
# Epoch 3/50
# 2/2 [==============================] - 0s 80ms/step - loss: 1.0784 - accuracy: 0.2909
# Epoch 4/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0476 - accuracy: 0.4182
# Epoch 5/50
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0228 - accuracy: 0.4545
# Epoch 6/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.0014 - accuracy: 0.5636
# Epoch 7/50
# 2/2 [==============================] - 0s 50ms/step - loss: 0.9810 - accuracy: 0.5455
# Epoch 8/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.9635 - accuracy: 0.5455
# Epoch 9/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9460 - accuracy: 0.5273
# Epoch 10/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9293 - accuracy: 0.5273
# Epoch 11/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9134 - accuracy: 0.5273
# Epoch 12/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.8970 - accuracy: 0.5273
# Epoch 13/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8796 - accuracy: 0.5455
# Epoch 14/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.8626 - accuracy: 0.5818
# Epoch 15/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8440 - accuracy: 0.6000
# Epoch 16/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8265 - accuracy: 0.6364
# Epoch 17/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8118 - accuracy: 0.6727
# Epoch 18/50
# 2/2 [==============================] - 0s 166ms/step - loss: 0.7905 - accuracy: 0.6909
# Epoch 19/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7743 - accuracy: 0.7455
# Epoch 20/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.7556 - accuracy: 0.7636
# Epoch 21/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7407 - accuracy: 0.7636
# Epoch 22/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7207 - accuracy: 0.7818
# Epoch 23/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7038 - accuracy: 0.8182
# Epoch 24/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6871 - accuracy: 0.8182
# Epoch 25/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6712 - accuracy: 0.8182
# Epoch 26/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6540 - accuracy: 0.8182
# Epoch 27/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6391 - accuracy: 0.8182
# Epoch 28/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6230 - accuracy: 0.8364
# Epoch 29/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6072 - accuracy: 0.8545
# Epoch 30/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5918 - accuracy: 0.8545
# Epoch 31/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5769 - accuracy: 0.8545
# Epoch 32/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5638 - accuracy: 0.8545
# Epoch 33/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5502 - accuracy: 0.8545
# Epoch 34/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.5366 - accuracy: 0.8545
# Epoch 35/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5240 - accuracy: 0.8364
# Epoch 36/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5100 - accuracy: 0.8364
# Epoch 37/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4982 - accuracy: 0.8364
# Epoch 38/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4858 - accuracy: 0.8909
# Epoch 39/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4743 - accuracy: 0.8727
# Epoch 40/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4634 - accuracy: 0.8727
# Epoch 41/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4528 - accuracy: 0.8727
# Epoch 42/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4428 - accuracy: 0.8727
# Epoch 43/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4325 - accuracy: 0.8727
# Epoch 44/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4231 - accuracy: 0.8727
# Epoch 45/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4144 - accuracy: 0.8909
# Epoch 46/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4063 - accuracy: 0.8909
# Epoch 47/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3964 - accuracy: 0.8909
# Epoch 48/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3882 - accuracy: 0.8909
# Epoch 49/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3797 - accuracy: 0.9091
# Epoch 50/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3731 - accuracy: 0.9091
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 7/7 [==============================] - 2s 11ms/step - loss: 1.3698 - accuracy: 0.3800
# Epoch 2/50
# 7/7 [==============================] - 0s 19ms/step - loss: 1.3404 - accuracy: 0.4400
# Epoch 3/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.3132 - accuracy: 0.6500
# Epoch 4/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2901 - accuracy: 0.5350
# Epoch 5/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2608 - accuracy: 0.6000
# Epoch 6/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2339 - accuracy: 0.7350
# Epoch 7/50
# 7/7 [==============================] - 0s 12ms/step - loss: 1.2009 - accuracy: 0.7600
# Epoch 8/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1687 - accuracy: 0.8400
# Epoch 9/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1325 - accuracy: 0.9300
# Epoch 10/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0918 - accuracy: 0.9850
# Epoch 11/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0450 - accuracy: 0.9900
# Epoch 12/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0003 - accuracy: 0.9750
# Epoch 13/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9525 - accuracy: 0.9550
# Epoch 14/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.9007 - accuracy: 0.9750
# Epoch 15/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8501 - accuracy: 0.9750
# Epoch 16/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.7947 - accuracy: 0.9900
# Epoch 17/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.7470 - accuracy: 0.9900
# Epoch 18/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6952 - accuracy: 0.9900
# Epoch 19/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6432 - accuracy: 0.9900
# Epoch 20/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.5996 - accuracy: 0.9900
# Epoch 21/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5532 - accuracy: 0.9850
# Epoch 22/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5157 - accuracy: 0.9850
# Epoch 23/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4730 - accuracy: 0.9900
# Epoch 24/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4375 - accuracy: 0.9900
# Epoch 25/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4058 - accuracy: 0.9900
# Epoch 26/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3737 - accuracy: 0.9900
# Epoch 27/50
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3449 - accuracy: 0.9900
# Epoch 28/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3239 - accuracy: 0.9900
# Epoch 29/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2979 - accuracy: 0.9900
# Epoch 30/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2730 - accuracy: 0.9900
# Epoch 31/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2561 - accuracy: 0.9900
# Epoch 32/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2428 - accuracy: 0.9900
# Epoch 33/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2230 - accuracy: 0.9900
# Epoch 34/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2090 - accuracy: 0.9900
# Epoch 35/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1954 - accuracy: 0.9900
# Epoch 36/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1830 - accuracy: 0.9900
# Epoch 37/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1724 - accuracy: 0.9900
# Epoch 38/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1628 - accuracy: 0.9900
# Epoch 39/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1539 - accuracy: 0.9900
# Epoch 40/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1473 - accuracy: 0.9900
# Epoch 41/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1398 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1342 - accuracy: 0.9900
# Epoch 43/50
# 7/7 [==============================] - 0s 30ms/step - loss: 0.1251 - accuracy: 0.9850
# Epoch 44/50
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1255 - accuracy: 0.9900
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.9900
# Epoch 46/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1147 - accuracy: 0.9850
# Epoch 47/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1120 - accuracy: 0.9900
# Epoch 48/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1008 - accuracy: 0.9850
# Epoch 49/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0973 - accuracy: 0.9900
# Epoch 50/50
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0938 - accuracy: 0.9900
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 0s 9ms/step
# 7/7 [==============================] - 0s 5ms/step
# Epoch 1/100
# 2/2 [==============================] - 2s 353ms/step - loss: 1.3916 - accuracy: 0.2045 - val_loss: 1.4373 - val_accuracy: 0.0909
# Epoch 2/100
# 2/2 [==============================] - 0s 102ms/step - loss: 1.3702 - accuracy: 0.3864 - val_loss: 1.4448 - val_accuracy: 0.1818
# Epoch 3/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.3557 - accuracy: 0.4091 - val_loss: 1.4548 - val_accuracy: 0.1818
# Epoch 4/100
# 2/2 [==============================] - 0s 94ms/step - loss: 1.3415 - accuracy: 0.4091 - val_loss: 1.4663 - val_accuracy: 0.1818
# Epoch 5/100
# 2/2 [==============================] - 0s 118ms/step - loss: 1.3314 - accuracy: 0.4091 - val_loss: 1.4807 - val_accuracy: 0.1818
# Epoch 6/100
# 2/2 [==============================] - 0s 88ms/step - loss: 1.3225 - accuracy: 0.4091 - val_loss: 1.4964 - val_accuracy: 0.1818
# Epoch 7/100
# 2/2 [==============================] - 0s 146ms/step - loss: 1.3161 - accuracy: 0.4091 - val_loss: 1.5149 - val_accuracy: 0.0909
# Epoch 8/100
# 2/2 [==============================] - 0s 98ms/step - loss: 1.3075 - accuracy: 0.4091 - val_loss: 1.5308 - val_accuracy: 0.0909
# Epoch 9/100
# 2/2 [==============================] - 0s 264ms/step - loss: 1.3041 - accuracy: 0.4091 - val_loss: 1.5470 - val_accuracy: 0.0909
# Epoch 10/100
# 2/2 [==============================] - 0s 98ms/step - loss: 1.2992 - accuracy: 0.4091 - val_loss: 1.5605 - val_accuracy: 0.0909
# Epoch 11/100
# 2/2 [==============================] - 0s 126ms/step - loss: 1.2958 - accuracy: 0.4091 - val_loss: 1.5743 - val_accuracy: 0.0909
# Epoch 12/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2934 - accuracy: 0.4091 - val_loss: 1.5883 - val_accuracy: 0.0909
# Epoch 13/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2897 - accuracy: 0.4091 - val_loss: 1.6015 - val_accuracy: 0.0909
# Epoch 14/100
# 2/2 [==============================] - 0s 124ms/step - loss: 1.2866 - accuracy: 0.4091 - val_loss: 1.6142 - val_accuracy: 0.0909
# Epoch 15/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.2842 - accuracy: 0.4091 - val_loss: 1.6265 - val_accuracy: 0.0909
# Epoch 16/100
# 2/2 [==============================] - 0s 108ms/step - loss: 1.2815 - accuracy: 0.4091 - val_loss: 1.6380 - val_accuracy: 0.0909
# Epoch 17/100
# 2/2 [==============================] - 0s 109ms/step - loss: 1.2792 - accuracy: 0.4091 - val_loss: 1.6484 - val_accuracy: 0.0909
# Epoch 18/100
# 2/2 [==============================] - 0s 122ms/step - loss: 1.2778 - accuracy: 0.4091 - val_loss: 1.6573 - val_accuracy: 0.0909
# Epoch 19/100
# 2/2 [==============================] - 0s 75ms/step - loss: 1.2767 - accuracy: 0.4091 - val_loss: 1.6624 - val_accuracy: 0.0909
# Epoch 20/100
# 2/2 [==============================] - 0s 130ms/step - loss: 1.2752 - accuracy: 0.4091 - val_loss: 1.6663 - val_accuracy: 0.0909
# Epoch 21/100
# 2/2 [==============================] - 0s 174ms/step - loss: 1.2723 - accuracy: 0.4091 - val_loss: 1.6703 - val_accuracy: 0.0909
# Epoch 22/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2711 - accuracy: 0.4091 - val_loss: 1.6745 - val_accuracy: 0.0909
# Epoch 23/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2693 - accuracy: 0.4091 - val_loss: 1.6803 - val_accuracy: 0.0909
# Epoch 24/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.2674 - accuracy: 0.4091 - val_loss: 1.6900 - val_accuracy: 0.0909
# Epoch 25/100
# 2/2 [==============================] - 0s 127ms/step - loss: 1.2657 - accuracy: 0.4091 - val_loss: 1.6983 - val_accuracy: 0.0909
# Epoch 26/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1.2633 - accuracy: 0.4091 - val_loss: 1.7048 - val_accuracy: 0.0909
# Epoch 27/100
# 2/2 [==============================] - 0s 175ms/step - loss: 1.2612 - accuracy: 0.4091 - val_loss: 1.7120 - val_accuracy: 0.0909
# Epoch 28/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2592 - accuracy: 0.4091 - val_loss: 1.7235 - val_accuracy: 0.0909
# Epoch 29/100
# 2/2 [==============================] - 0s 175ms/step - loss: 1.2567 - accuracy: 0.4091 - val_loss: 1.7339 - val_accuracy: 0.0909
# Epoch 30/100
# 2/2 [==============================] - 0s 60ms/step - loss: 1.2543 - accuracy: 0.4091 - val_loss: 1.7443 - val_accuracy: 0.0909
# Epoch 31/100
# 2/2 [==============================] - 0s 269ms/step - loss: 1.2525 - accuracy: 0.4091 - val_loss: 1.7535 - val_accuracy: 0.0909
# Epoch 32/100
# 2/2 [==============================] - 0s 86ms/step - loss: 1.2503 - accuracy: 0.4091 - val_loss: 1.7652 - val_accuracy: 0.0909
# Epoch 33/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.2479 - accuracy: 0.4091 - val_loss: 1.7770 - val_accuracy: 0.0909
# Epoch 34/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.2460 - accuracy: 0.4091 - val_loss: 1.7904 - val_accuracy: 0.0909
# Epoch 35/100
# 2/2 [==============================] - 0s 97ms/step - loss: 1.2441 - accuracy: 0.4091 - val_loss: 1.8105 - val_accuracy: 0.0909
# Epoch 36/100
# 2/2 [==============================] - 0s 75ms/step - loss: 1.2420 - accuracy: 0.4091 - val_loss: 1.8327 - val_accuracy: 0.0909
# Epoch 37/100
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2407 - accuracy: 0.4091 - val_loss: 1.8575 - val_accuracy: 0.0909
# Epoch 38/100
# 2/2 [==============================] - 0s 95ms/step - loss: 1.2410 - accuracy: 0.4091 - val_loss: 1.8829 - val_accuracy: 0.0909
# Epoch 39/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2403 - accuracy: 0.4091 - val_loss: 1.9026 - val_accuracy: 0.0909
# Epoch 40/100
# 2/2 [==============================] - 0s 92ms/step - loss: 1.2402 - accuracy: 0.4091 - val_loss: 1.9154 - val_accuracy: 0.0909
# Epoch 41/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2378 - accuracy: 0.4091 - val_loss: 1.9193 - val_accuracy: 0.0909
# Epoch 42/100
# 2/2 [==============================] - 0s 119ms/step - loss: 1.2349 - accuracy: 0.4091 - val_loss: 1.9228 - val_accuracy: 0.0909
# Epoch 43/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.2313 - accuracy: 0.4318 - val_loss: 1.9247 - val_accuracy: 0.0909
# Epoch 44/100
# 2/2 [==============================] - 0s 97ms/step - loss: 1.2287 - accuracy: 0.4318 - val_loss: 1.9265 - val_accuracy: 0.0909
# Epoch 45/100
# 2/2 [==============================] - 0s 109ms/step - loss: 1.2253 - accuracy: 0.4318 - val_loss: 1.9250 - val_accuracy: 0.0909
# Epoch 46/100
# 2/2 [==============================] - 0s 88ms/step - loss: 1.2240 - accuracy: 0.4318 - val_loss: 1.9203 - val_accuracy: 0.0909
# Epoch 47/100
# 2/2 [==============================] - 0s 88ms/step - loss: 1.2226 - accuracy: 0.4318 - val_loss: 1.9191 - val_accuracy: 0.0909
# Epoch 48/100
# 2/2 [==============================] - 0s 113ms/step - loss: 1.2207 - accuracy: 0.4318 - val_loss: 1.9251 - val_accuracy: 0.0909
# Epoch 49/100
# 2/2 [==============================] - 0s 105ms/step - loss: 1.2188 - accuracy: 0.4318 - val_loss: 1.9368 - val_accuracy: 0.0909
# Epoch 50/100
# 2/2 [==============================] - 0s 98ms/step - loss: 1.2169 - accuracy: 0.4318 - val_loss: 1.9533 - val_accuracy: 0.0909
# Epoch 51/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2156 - accuracy: 0.4318 - val_loss: 1.9767 - val_accuracy: 0.0909
# Epoch 52/100
# 2/2 [==============================] - 0s 327ms/step - loss: 1.2148 - accuracy: 0.4318 - val_loss: 2.0017 - val_accuracy: 0.0909
# Epoch 53/100
# 2/2 [==============================] - 0s 147ms/step - loss: 1.2123 - accuracy: 0.4318 - val_loss: 2.0202 - val_accuracy: 0.0909
# Epoch 54/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.2106 - accuracy: 0.4318 - val_loss: 2.0373 - val_accuracy: 0.0909
# Epoch 55/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.2091 - accuracy: 0.4318 - val_loss: 2.0504 - val_accuracy: 0.0909
# Epoch 56/100
# 2/2 [==============================] - 0s 203ms/step - loss: 1.2069 - accuracy: 0.4318 - val_loss: 2.0637 - val_accuracy: 0.0909
# Epoch 57/100
# 2/2 [==============================] - 0s 254ms/step - loss: 1.2053 - accuracy: 0.4318 - val_loss: 2.0772 - val_accuracy: 0.0909
# Epoch 58/100
# 2/2 [==============================] - 0s 121ms/step - loss: 1.2047 - accuracy: 0.4318 - val_loss: 2.0876 - val_accuracy: 0.0909
# Epoch 59/100
# 2/2 [==============================] - 0s 190ms/step - loss: 1.2022 - accuracy: 0.4318 - val_loss: 2.0961 - val_accuracy: 0.0909
# Epoch 60/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.2006 - accuracy: 0.4318 - val_loss: 2.0995 - val_accuracy: 0.0909
# Epoch 61/100
# 2/2 [==============================] - 0s 193ms/step - loss: 1.2004 - accuracy: 0.4318 - val_loss: 2.1061 - val_accuracy: 0.0909
# Epoch 62/100
# 2/2 [==============================] - 0s 251ms/step - loss: 1.1983 - accuracy: 0.4091 - val_loss: 2.1200 - val_accuracy: 0.0909
# Epoch 63/100
# 2/2 [==============================] - 0s 141ms/step - loss: 1.1966 - accuracy: 0.4318 - val_loss: 2.1337 - val_accuracy: 0.0909
# Epoch 64/100
# 2/2 [==============================] - 0s 92ms/step - loss: 1.1957 - accuracy: 0.4545 - val_loss: 2.1480 - val_accuracy: 0.0909
# Epoch 65/100
# 2/2 [==============================] - 0s 336ms/step - loss: 1.1940 - accuracy: 0.4545 - val_loss: 2.1657 - val_accuracy: 0.0909
# Epoch 66/100
# 2/2 [==============================] - 0s 81ms/step - loss: 1.1918 - accuracy: 0.4545 - val_loss: 2.1852 - val_accuracy: 0.0909
# Epoch 67/100
# 2/2 [==============================] - 0s 314ms/step - loss: 1.1903 - accuracy: 0.4773 - val_loss: 2.2089 - val_accuracy: 0.0909
# Epoch 68/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.1888 - accuracy: 0.4545 - val_loss: 2.2336 - val_accuracy: 0.0909
# Epoch 69/100
# 2/2 [==============================] - 0s 258ms/step - loss: 1.1874 - accuracy: 0.4545 - val_loss: 2.2583 - val_accuracy: 0.0909
# Epoch 70/100
# 2/2 [==============================] - 0s 129ms/step - loss: 1.1857 - accuracy: 0.4545 - val_loss: 2.2859 - val_accuracy: 0.0909
# Epoch 71/100
# 2/2 [==============================] - 0s 117ms/step - loss: 1.1864 - accuracy: 0.4545 - val_loss: 2.3112 - val_accuracy: 0.0909
# Epoch 72/100
# 2/2 [==============================] - 0s 160ms/step - loss: 1.1858 - accuracy: 0.4545 - val_loss: 2.3369 - val_accuracy: 0.0909
# Epoch 73/100
# 2/2 [==============================] - 0s 159ms/step - loss: 1.1855 - accuracy: 0.4545 - val_loss: 2.3630 - val_accuracy: 0.0909
# Epoch 74/100
# 2/2 [==============================] - 0s 90ms/step - loss: 1.1835 - accuracy: 0.4545 - val_loss: 2.3862 - val_accuracy: 0.0909
# Epoch 75/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.1815 - accuracy: 0.4545 - val_loss: 2.4028 - val_accuracy: 0.0909
# Epoch 76/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.1780 - accuracy: 0.4545 - val_loss: 2.4184 - val_accuracy: 0.0909
# Epoch 77/100
# 2/2 [==============================] - 0s 138ms/step - loss: 1.1777 - accuracy: 0.4545 - val_loss: 2.4297 - val_accuracy: 0.0909
# Epoch 78/100
# 2/2 [==============================] - 0s 178ms/step - loss: 1.1746 - accuracy: 0.4545 - val_loss: 2.4448 - val_accuracy: 0.0909
# Epoch 79/100
# 2/2 [==============================] - 0s 110ms/step - loss: 1.1737 - accuracy: 0.4545 - val_loss: 2.4650 - val_accuracy: 0.0909
# Epoch 80/100
# 2/2 [==============================] - 0s 136ms/step - loss: 1.1717 - accuracy: 0.4318 - val_loss: 2.4834 - val_accuracy: 0.0909
# Epoch 81/100
# 2/2 [==============================] - 0s 108ms/step - loss: 1.1702 - accuracy: 0.4773 - val_loss: 2.5055 - val_accuracy: 0.0909
# Epoch 82/100
# 2/2 [==============================] - 0s 180ms/step - loss: 1.1700 - accuracy: 0.4545 - val_loss: 2.5295 - val_accuracy: 0.0909
# Epoch 83/100
# 2/2 [==============================] - 0s 156ms/step - loss: 1.1677 - accuracy: 0.4545 - val_loss: 2.5475 - val_accuracy: 0.0909
# Epoch 84/100
# 2/2 [==============================] - 0s 138ms/step - loss: 1.1671 - accuracy: 0.4545 - val_loss: 2.5662 - val_accuracy: 0.0909
# Epoch 85/100
# 2/2 [==============================] - 0s 247ms/step - loss: 1.1647 - accuracy: 0.4318 - val_loss: 2.5872 - val_accuracy: 0.0909
# Epoch 86/100
# 2/2 [==============================] - 0s 137ms/step - loss: 1.1633 - accuracy: 0.4318 - val_loss: 2.5994 - val_accuracy: 0.0909
# Epoch 87/100
# 2/2 [==============================] - 0s 135ms/step - loss: 1.1623 - accuracy: 0.4545 - val_loss: 2.6144 - val_accuracy: 0.0909
# Epoch 88/100
# 2/2 [==============================] - 0s 131ms/step - loss: 1.1609 - accuracy: 0.4545 - val_loss: 2.6338 - val_accuracy: 0.0909
# Epoch 89/100
# 2/2 [==============================] - 0s 265ms/step - loss: 1.1601 - accuracy: 0.4545 - val_loss: 2.6522 - val_accuracy: 0.0909
# Epoch 90/100
# 2/2 [==============================] - 0s 139ms/step - loss: 1.1590 - accuracy: 0.4545 - val_loss: 2.6717 - val_accuracy: 0.0909
# Epoch 91/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.1592 - accuracy: 0.4318 - val_loss: 2.6877 - val_accuracy: 0.0909
# Epoch 92/100
# 2/2 [==============================] - 0s 120ms/step - loss: 1.1563 - accuracy: 0.4318 - val_loss: 2.7012 - val_accuracy: 0.0909
# Epoch 93/100
# 2/2 [==============================] - 0s 143ms/step - loss: 1.1541 - accuracy: 0.4545 - val_loss: 2.7195 - val_accuracy: 0.0909
# Epoch 94/100
# 2/2 [==============================] - 0s 127ms/step - loss: 1.1521 - accuracy: 0.4318 - val_loss: 2.7446 - val_accuracy: 0.0909
# Epoch 95/100
# 2/2 [==============================] - 0s 169ms/step - loss: 1.1510 - accuracy: 0.4545 - val_loss: 2.7687 - val_accuracy: 0.0909
# Epoch 96/100
# 2/2 [==============================] - 0s 122ms/step - loss: 1.1498 - accuracy: 0.4545 - val_loss: 2.7911 - val_accuracy: 0.0909
# Epoch 97/100
# 2/2 [==============================] - 0s 148ms/step - loss: 1.1505 - accuracy: 0.4545 - val_loss: 2.8179 - val_accuracy: 0.0909
# Epoch 98/100
# 2/2 [==============================] - 0s 160ms/step - loss: 1.1499 - accuracy: 0.4545 - val_loss: 2.8308 - val_accuracy: 0.0909
# Epoch 99/100
# 2/2 [==============================] - 0s 175ms/step - loss: 1.1497 - accuracy: 0.4773 - val_loss: 2.8415 - val_accuracy: 0.0909
# Epoch 100/100
# 2/2 [==============================] - 0s 142ms/step - loss: 1.1492 - accuracy: 0.4773 - val_loss: 2.8470 - val_accuracy: 0.0909
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic)
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1)
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2)
print("Predicted Labels - Combined AI:", predicted_labels_combined)
# Out:
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 100ms/step
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x164f428e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 121ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x164efc540> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 209ms/step
# Predicted Labels - Generic AI: ['Engineering']
# Predicted Labels - Parallel AI 1: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Parallel AI 2: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Combined AI: ['Civil Engineering']
