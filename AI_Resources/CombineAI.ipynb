# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=25, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=50)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

data_3 = pd.read_csv("data_3.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using the concatenated output of the parallel AIs and the third dataset
model_combined.fit(combined_output, y_data_3_encoded[:min_rows], epochs=100, validation_split=0.2)

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/25
# 1/1 [==============================] - 4s 4s/step - loss: 0.7077 - accuracy: 0.7500 - val_loss: 1.3092 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 1/1 [==============================] - 0s 207ms/step - loss: 0.5971 - accuracy: 0.7500 - val_loss: 1.1949 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 1/1 [==============================] - 0s 109ms/step - loss: 0.5070 - accuracy: 0.7500 - val_loss: 1.1102 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 1/1 [==============================] - 0s 99ms/step - loss: 0.4376 - accuracy: 0.7500 - val_loss: 1.0654 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 1/1 [==============================] - 0s 142ms/step - loss: 0.3872 - accuracy: 1.0000 - val_loss: 1.0508 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 1/1 [==============================] - 0s 282ms/step - loss: 0.3487 - accuracy: 1.0000 - val_loss: 1.0634 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 1/1 [==============================] - 0s 280ms/step - loss: 0.3160 - accuracy: 1.0000 - val_loss: 1.0987 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 1/1 [==============================] - 0s 206ms/step - loss: 0.2862 - accuracy: 1.0000 - val_loss: 1.1530 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 1/1 [==============================] - 0s 291ms/step - loss: 0.2590 - accuracy: 1.0000 - val_loss: 1.2215 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 1/1 [==============================] - 0s 298ms/step - loss: 0.2335 - accuracy: 1.0000 - val_loss: 1.3056 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 1/1 [==============================] - 0s 179ms/step - loss: 0.2104 - accuracy: 1.0000 - val_loss: 1.3999 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 1/1 [==============================] - 0s 188ms/step - loss: 0.1907 - accuracy: 1.0000 - val_loss: 1.4968 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 1/1 [==============================] - 0s 151ms/step - loss: 0.1743 - accuracy: 1.0000 - val_loss: 1.5907 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 1/1 [==============================] - 0s 140ms/step - loss: 0.1597 - accuracy: 1.0000 - val_loss: 1.6799 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 1/1 [==============================] - 0s 199ms/step - loss: 0.1465 - accuracy: 1.0000 - val_loss: 1.7617 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 1/1 [==============================] - 0s 155ms/step - loss: 0.1343 - accuracy: 1.0000 - val_loss: 1.8343 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1229 - accuracy: 1.0000 - val_loss: 1.8974 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 1/1 [==============================] - 0s 109ms/step - loss: 0.1122 - accuracy: 1.0000 - val_loss: 1.9532 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 1/1 [==============================] - 0s 140ms/step - loss: 0.1023 - accuracy: 1.0000 - val_loss: 2.0013 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0929 - accuracy: 1.0000 - val_loss: 2.0423 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0843 - accuracy: 1.0000 - val_loss: 2.0764 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0768 - accuracy: 1.0000 - val_loss: 2.1080 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 2.1393 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0634 - accuracy: 1.0000 - val_loss: 2.1719 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 2.2055 - val_accuracy: 0.0000e+00
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 2/2 [==============================] - 1s 14ms/step - loss: 1.0934 - accuracy: 0.3636
# Epoch 2/50
# 2/2 [==============================] - 0s 17ms/step - loss: 1.0661 - accuracy: 0.5273
# Epoch 3/50
# 2/2 [==============================] - 0s 39ms/step - loss: 1.0378 - accuracy: 0.5273
# Epoch 4/50
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0155 - accuracy: 0.5091
# Epoch 5/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9949 - accuracy: 0.5091
# Epoch 6/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9763 - accuracy: 0.5091
# Epoch 7/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9581 - accuracy: 0.5091
# Epoch 8/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.9412 - accuracy: 0.5273
# Epoch 9/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9243 - accuracy: 0.5091
# Epoch 10/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.9067 - accuracy: 0.5455
# Epoch 11/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.8885 - accuracy: 0.5273
# Epoch 12/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8713 - accuracy: 0.5636
# Epoch 13/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8506 - accuracy: 0.5636
# Epoch 14/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8305 - accuracy: 0.6364
# Epoch 15/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8119 - accuracy: 0.6909
# Epoch 16/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.7926 - accuracy: 0.7273
# Epoch 17/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.7723 - accuracy: 0.7455
# Epoch 18/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7553 - accuracy: 0.7818
# Epoch 19/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7341 - accuracy: 0.7818
# Epoch 20/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.7158 - accuracy: 0.7818
# Epoch 21/50
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6961 - accuracy: 0.7818
# Epoch 22/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6778 - accuracy: 0.8182
# Epoch 23/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6584 - accuracy: 0.8182
# Epoch 24/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6410 - accuracy: 0.8182
# Epoch 25/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6229 - accuracy: 0.8182
# Epoch 26/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.6074 - accuracy: 0.8182
# Epoch 27/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5897 - accuracy: 0.8182
# Epoch 28/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5754 - accuracy: 0.8182
# Epoch 29/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5609 - accuracy: 0.8364
# Epoch 30/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5462 - accuracy: 0.8364
# Epoch 31/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5313 - accuracy: 0.8364
# Epoch 32/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5181 - accuracy: 0.8364
# Epoch 33/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5061 - accuracy: 0.8545
# Epoch 34/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.4935 - accuracy: 0.8545
# Epoch 35/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4816 - accuracy: 0.8727
# Epoch 36/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4715 - accuracy: 0.8727
# Epoch 37/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4597 - accuracy: 0.8545
# Epoch 38/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4485 - accuracy: 0.8545
# Epoch 39/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4399 - accuracy: 0.8545
# Epoch 40/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4316 - accuracy: 0.8727
# Epoch 41/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4208 - accuracy: 0.8909
# Epoch 42/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4121 - accuracy: 0.8909
# Epoch 43/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4027 - accuracy: 0.8909
# Epoch 44/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3945 - accuracy: 0.8909
# Epoch 45/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3861 - accuracy: 0.8909
# Epoch 46/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3780 - accuracy: 0.8909
# Epoch 47/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3700 - accuracy: 0.8909
# Epoch 48/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3623 - accuracy: 0.8909
# Epoch 49/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3558 - accuracy: 0.8909
# Epoch 50/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3485 - accuracy: 0.8909
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 7/7 [==============================] - 2s 6ms/step - loss: 1.3876 - accuracy: 0.2350
# Epoch 2/50
# 7/7 [==============================] - 0s 27ms/step - loss: 1.3586 - accuracy: 0.4800
# Epoch 3/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.3446 - accuracy: 0.2850
# Epoch 4/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.3226 - accuracy: 0.3950
# Epoch 5/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.3072 - accuracy: 0.6750
# Epoch 6/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2827 - accuracy: 0.7400
# Epoch 7/50
# 7/7 [==============================] - 0s 17ms/step - loss: 1.2625 - accuracy: 0.8750
# Epoch 8/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2392 - accuracy: 0.8650
# Epoch 9/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2148 - accuracy: 0.9500
# Epoch 10/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1873 - accuracy: 0.9500
# Epoch 11/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1579 - accuracy: 0.9550
# Epoch 12/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.1259 - accuracy: 0.9900
# Epoch 13/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0920 - accuracy: 0.9900
# Epoch 14/50
# 7/7 [==============================] - 0s 32ms/step - loss: 1.0564 - accuracy: 0.9800
# Epoch 15/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0184 - accuracy: 0.9950
# Epoch 16/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9833 - accuracy: 0.9900
# Epoch 17/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.9436 - accuracy: 0.9600
# Epoch 18/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8999 - accuracy: 0.9900
# Epoch 19/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.8610 - accuracy: 0.9500
# Epoch 20/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8156 - accuracy: 0.9600
# Epoch 21/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7729 - accuracy: 0.9900
# Epoch 22/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7327 - accuracy: 0.9800
# Epoch 23/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6873 - accuracy: 0.9850
# Epoch 24/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6443 - accuracy: 0.9900
# Epoch 25/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6046 - accuracy: 0.9900
# Epoch 26/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.5676 - accuracy: 0.9900
# Epoch 27/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.5345 - accuracy: 0.9900
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4973 - accuracy: 0.9950
# Epoch 29/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4621 - accuracy: 0.9900
# Epoch 30/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4346 - accuracy: 0.9850
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4040 - accuracy: 0.9900
# Epoch 32/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3763 - accuracy: 0.9900
# Epoch 33/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3537 - accuracy: 0.9900
# Epoch 34/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3299 - accuracy: 0.9900
# Epoch 35/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3124 - accuracy: 0.9900
# Epoch 36/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.2877 - accuracy: 0.9900
# Epoch 37/50
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2691 - accuracy: 0.9900
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2530 - accuracy: 0.9900
# Epoch 39/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2374 - accuracy: 0.9900
# Epoch 40/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2240 - accuracy: 0.9900
# Epoch 41/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2110 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1989 - accuracy: 0.9900
# Epoch 43/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1883 - accuracy: 0.9900
# Epoch 44/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1767 - accuracy: 0.9900
# Epoch 45/50
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1697 - accuracy: 0.9900
# Epoch 46/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1601 - accuracy: 0.9900
# Epoch 47/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1538 - accuracy: 0.9900
# Epoch 48/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1449 - accuracy: 0.9900
# Epoch 49/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1381 - accuracy: 0.9900
# Epoch 50/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1326 - accuracy: 0.9900
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 0s 33ms/step
# 7/7 [==============================] - 0s 2ms/step
# Epoch 1/100
# 2/2 [==============================] - 2s 590ms/step - loss: 1.3912 - accuracy: 0.2500 - val_loss: 1.3999 - val_accuracy: 0.0909
# Epoch 2/100
# 2/2 [==============================] - 0s 152ms/step - loss: 1.3700 - accuracy: 0.2727 - val_loss: 1.4169 - val_accuracy: 0.0909
# Epoch 3/100
# 2/2 [==============================] - 0s 112ms/step - loss: 1.3539 - accuracy: 0.3864 - val_loss: 1.4360 - val_accuracy: 0.0909
# Epoch 4/100
# 2/2 [==============================] - 0s 141ms/step - loss: 1.3409 - accuracy: 0.4318 - val_loss: 1.4534 - val_accuracy: 0.0909
# Epoch 5/100
# 2/2 [==============================] - 0s 140ms/step - loss: 1.3279 - accuracy: 0.4091 - val_loss: 1.4708 - val_accuracy: 0.0909
# Epoch 6/100
# 2/2 [==============================] - 0s 99ms/step - loss: 1.3182 - accuracy: 0.4091 - val_loss: 1.4919 - val_accuracy: 0.0909
# Epoch 7/100
# 2/2 [==============================] - 0s 142ms/step - loss: 1.3109 - accuracy: 0.4091 - val_loss: 1.5152 - val_accuracy: 0.0909
# Epoch 8/100
# 2/2 [==============================] - 0s 141ms/step - loss: 1.3046 - accuracy: 0.4091 - val_loss: 1.5376 - val_accuracy: 0.0909
# Epoch 9/100
# 2/2 [==============================] - 0s 99ms/step - loss: 1.3001 - accuracy: 0.4091 - val_loss: 1.5588 - val_accuracy: 0.0909
# Epoch 10/100
# 2/2 [==============================] - 0s 139ms/step - loss: 1.2964 - accuracy: 0.4091 - val_loss: 1.5805 - val_accuracy: 0.0909
# Epoch 11/100
# 2/2 [==============================] - 0s 114ms/step - loss: 1.2925 - accuracy: 0.4091 - val_loss: 1.5990 - val_accuracy: 0.0909
# Epoch 12/100
# 2/2 [==============================] - 0s 126ms/step - loss: 1.2903 - accuracy: 0.4091 - val_loss: 1.6179 - val_accuracy: 0.0909
# Epoch 13/100
# 2/2 [==============================] - 0s 97ms/step - loss: 1.2885 - accuracy: 0.4091 - val_loss: 1.6332 - val_accuracy: 0.0909
# Epoch 14/100
# 2/2 [==============================] - 0s 115ms/step - loss: 1.2866 - accuracy: 0.4091 - val_loss: 1.6446 - val_accuracy: 0.0909
# Epoch 15/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.2846 - accuracy: 0.4091 - val_loss: 1.6516 - val_accuracy: 0.0909
# Epoch 16/100
# 2/2 [==============================] - 0s 120ms/step - loss: 1.2825 - accuracy: 0.4091 - val_loss: 1.6526 - val_accuracy: 0.0909
# Epoch 17/100
# 2/2 [==============================] - 0s 107ms/step - loss: 1.2802 - accuracy: 0.4091 - val_loss: 1.6505 - val_accuracy: 0.0909
# Epoch 18/100
# 2/2 [==============================] - 0s 119ms/step - loss: 1.2782 - accuracy: 0.4091 - val_loss: 1.6486 - val_accuracy: 0.0909
# Epoch 19/100
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2755 - accuracy: 0.4091 - val_loss: 1.6447 - val_accuracy: 0.0909
# Epoch 20/100
# 2/2 [==============================] - 0s 132ms/step - loss: 1.2734 - accuracy: 0.4318 - val_loss: 1.6424 - val_accuracy: 0.0909
# Epoch 21/100
# 2/2 [==============================] - 0s 160ms/step - loss: 1.2707 - accuracy: 0.4318 - val_loss: 1.6413 - val_accuracy: 0.0909
# Epoch 22/100
# 2/2 [==============================] - 0s 318ms/step - loss: 1.2691 - accuracy: 0.4318 - val_loss: 1.6406 - val_accuracy: 0.0909
# Epoch 23/100
# 2/2 [==============================] - 0s 129ms/step - loss: 1.2668 - accuracy: 0.4318 - val_loss: 1.6428 - val_accuracy: 0.0909
# Epoch 24/100
# 2/2 [==============================] - 0s 81ms/step - loss: 1.2646 - accuracy: 0.4318 - val_loss: 1.6507 - val_accuracy: 0.0909
# Epoch 25/100
# 2/2 [==============================] - 0s 82ms/step - loss: 1.2625 - accuracy: 0.4318 - val_loss: 1.6598 - val_accuracy: 0.0909
# Epoch 26/100
# 2/2 [==============================] - 0s 126ms/step - loss: 1.2607 - accuracy: 0.4318 - val_loss: 1.6686 - val_accuracy: 0.0909
# Epoch 27/100
# 2/2 [==============================] - 0s 67ms/step - loss: 1.2577 - accuracy: 0.4318 - val_loss: 1.6795 - val_accuracy: 0.0909
# Epoch 28/100
# 2/2 [==============================] - 0s 123ms/step - loss: 1.2565 - accuracy: 0.4318 - val_loss: 1.6891 - val_accuracy: 0.0909
# Epoch 29/100
# 2/2 [==============================] - 0s 105ms/step - loss: 1.2543 - accuracy: 0.4318 - val_loss: 1.6952 - val_accuracy: 0.0909
# Epoch 30/100
# 2/2 [==============================] - 0s 133ms/step - loss: 1.2521 - accuracy: 0.4318 - val_loss: 1.7023 - val_accuracy: 0.0909
# Epoch 31/100
# 2/2 [==============================] - 0s 147ms/step - loss: 1.2498 - accuracy: 0.4318 - val_loss: 1.7102 - val_accuracy: 0.0909
# Epoch 32/100
# 2/2 [==============================] - 0s 187ms/step - loss: 1.2482 - accuracy: 0.4318 - val_loss: 1.7144 - val_accuracy: 0.0909
# Epoch 33/100
# 2/2 [==============================] - 0s 136ms/step - loss: 1.2458 - accuracy: 0.4318 - val_loss: 1.7145 - val_accuracy: 0.0909
# Epoch 34/100
# 2/2 [==============================] - 0s 90ms/step - loss: 1.2432 - accuracy: 0.4318 - val_loss: 1.7103 - val_accuracy: 0.0909
# Epoch 35/100
# 2/2 [==============================] - 0s 116ms/step - loss: 1.2444 - accuracy: 0.4318 - val_loss: 1.7084 - val_accuracy: 0.0909
# Epoch 36/100
# 2/2 [==============================] - 0s 129ms/step - loss: 1.2414 - accuracy: 0.4318 - val_loss: 1.7131 - val_accuracy: 0.0909
# Epoch 37/100
# 2/2 [==============================] - 0s 325ms/step - loss: 1.2393 - accuracy: 0.4318 - val_loss: 1.7215 - val_accuracy: 0.0909
# Epoch 38/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.2379 - accuracy: 0.4318 - val_loss: 1.7325 - val_accuracy: 0.0909
# Epoch 39/100
# 2/2 [==============================] - 0s 109ms/step - loss: 1.2355 - accuracy: 0.4318 - val_loss: 1.7400 - val_accuracy: 0.0909
# Epoch 40/100
# 2/2 [==============================] - 0s 170ms/step - loss: 1.2333 - accuracy: 0.4318 - val_loss: 1.7474 - val_accuracy: 0.0909
# Epoch 41/100
# 2/2 [==============================] - 0s 120ms/step - loss: 1.2315 - accuracy: 0.4318 - val_loss: 1.7578 - val_accuracy: 0.0909
# Epoch 42/100
# 2/2 [==============================] - 0s 177ms/step - loss: 1.2301 - accuracy: 0.4318 - val_loss: 1.7699 - val_accuracy: 0.0909
# Epoch 43/100
# 2/2 [==============================] - 0s 339ms/step - loss: 1.2282 - accuracy: 0.4318 - val_loss: 1.7790 - val_accuracy: 0.0909
# Epoch 44/100
# 2/2 [==============================] - 0s 119ms/step - loss: 1.2275 - accuracy: 0.4318 - val_loss: 1.7877 - val_accuracy: 0.0909
# Epoch 45/100
# 2/2 [==============================] - 0s 134ms/step - loss: 1.2258 - accuracy: 0.4318 - val_loss: 1.8031 - val_accuracy: 0.0909
# Epoch 46/100
# 2/2 [==============================] - 0s 114ms/step - loss: 1.2243 - accuracy: 0.4318 - val_loss: 1.8158 - val_accuracy: 0.0909
# Epoch 47/100
# 2/2 [==============================] - 0s 285ms/step - loss: 1.2229 - accuracy: 0.4318 - val_loss: 1.8255 - val_accuracy: 0.0909
# Epoch 48/100
# 2/2 [==============================] - 0s 144ms/step - loss: 1.2209 - accuracy: 0.4318 - val_loss: 1.8332 - val_accuracy: 0.0909
# Epoch 49/100
# 2/2 [==============================] - 0s 98ms/step - loss: 1.2197 - accuracy: 0.4318 - val_loss: 1.8428 - val_accuracy: 0.0909
# Epoch 50/100
# 2/2 [==============================] - 0s 123ms/step - loss: 1.2184 - accuracy: 0.4318 - val_loss: 1.8557 - val_accuracy: 0.0909
# Epoch 51/100
# 2/2 [==============================] - 0s 170ms/step - loss: 1.2164 - accuracy: 0.4318 - val_loss: 1.8663 - val_accuracy: 0.0909
# Epoch 52/100
# 2/2 [==============================] - 0s 151ms/step - loss: 1.2153 - accuracy: 0.4318 - val_loss: 1.8735 - val_accuracy: 0.0909
# Epoch 53/100
# 2/2 [==============================] - 0s 108ms/step - loss: 1.2137 - accuracy: 0.4318 - val_loss: 1.8771 - val_accuracy: 0.0909
# Epoch 54/100
# 2/2 [==============================] - 0s 107ms/step - loss: 1.2116 - accuracy: 0.4318 - val_loss: 1.8844 - val_accuracy: 0.0909
# Epoch 55/100
# 2/2 [==============================] - 0s 159ms/step - loss: 1.2106 - accuracy: 0.4318 - val_loss: 1.8920 - val_accuracy: 0.0909
# Epoch 56/100
# 2/2 [==============================] - 0s 123ms/step - loss: 1.2100 - accuracy: 0.4318 - val_loss: 1.9019 - val_accuracy: 0.0909
# Epoch 57/100
# 2/2 [==============================] - 0s 153ms/step - loss: 1.2092 - accuracy: 0.4318 - val_loss: 1.9143 - val_accuracy: 0.0909
# Epoch 58/100
# 2/2 [==============================] - 0s 132ms/step - loss: 1.2072 - accuracy: 0.4318 - val_loss: 1.9232 - val_accuracy: 0.0909
# Epoch 59/100
# 2/2 [==============================] - 0s 186ms/step - loss: 1.2049 - accuracy: 0.4318 - val_loss: 1.9358 - val_accuracy: 0.0909
# Epoch 60/100
# 2/2 [==============================] - 0s 135ms/step - loss: 1.2040 - accuracy: 0.4318 - val_loss: 1.9470 - val_accuracy: 0.0909
# Epoch 61/100
# 2/2 [==============================] - 0s 107ms/step - loss: 1.2031 - accuracy: 0.4318 - val_loss: 1.9496 - val_accuracy: 0.0909
# Epoch 62/100
# 2/2 [==============================] - 0s 273ms/step - loss: 1.2009 - accuracy: 0.4318 - val_loss: 1.9474 - val_accuracy: 0.0909
# Epoch 63/100
# 2/2 [==============================] - 0s 91ms/step - loss: 1.2000 - accuracy: 0.4318 - val_loss: 1.9461 - val_accuracy: 0.0909
# Epoch 64/100
# 2/2 [==============================] - 0s 107ms/step - loss: 1.1989 - accuracy: 0.4318 - val_loss: 1.9519 - val_accuracy: 0.0909
# Epoch 65/100
# 2/2 [==============================] - 0s 121ms/step - loss: 1.1977 - accuracy: 0.4318 - val_loss: 1.9668 - val_accuracy: 0.0909
# Epoch 66/100
# 2/2 [==============================] - 0s 145ms/step - loss: 1.1960 - accuracy: 0.4318 - val_loss: 1.9842 - val_accuracy: 0.0909
# Epoch 67/100
# 2/2 [==============================] - 0s 172ms/step - loss: 1.1947 - accuracy: 0.4318 - val_loss: 1.9993 - val_accuracy: 0.0909
# Epoch 68/100
# 2/2 [==============================] - 0s 92ms/step - loss: 1.1941 - accuracy: 0.4318 - val_loss: 2.0116 - val_accuracy: 0.0909
# Epoch 69/100
# 2/2 [==============================] - 0s 114ms/step - loss: 1.1925 - accuracy: 0.4318 - val_loss: 2.0156 - val_accuracy: 0.0909
# Epoch 70/100
# 2/2 [==============================] - 0s 65ms/step - loss: 1.1902 - accuracy: 0.4318 - val_loss: 2.0217 - val_accuracy: 0.0909
# Epoch 71/100
# 2/2 [==============================] - 0s 155ms/step - loss: 1.1900 - accuracy: 0.4318 - val_loss: 2.0326 - val_accuracy: 0.0909
# Epoch 72/100
# 2/2 [==============================] - 0s 151ms/step - loss: 1.1884 - accuracy: 0.4318 - val_loss: 2.0463 - val_accuracy: 0.0909
# Epoch 73/100
# 2/2 [==============================] - 0s 103ms/step - loss: 1.1884 - accuracy: 0.4318 - val_loss: 2.0559 - val_accuracy: 0.0909
# Epoch 74/100
# 2/2 [==============================] - 0s 93ms/step - loss: 1.1856 - accuracy: 0.4318 - val_loss: 2.0570 - val_accuracy: 0.0909
# Epoch 75/100
# 2/2 [==============================] - 0s 95ms/step - loss: 1.1843 - accuracy: 0.4318 - val_loss: 2.0561 - val_accuracy: 0.0909
# Epoch 76/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.1829 - accuracy: 0.4318 - val_loss: 2.0563 - val_accuracy: 0.0909
# Epoch 77/100
# 2/2 [==============================] - 0s 128ms/step - loss: 1.1811 - accuracy: 0.4318 - val_loss: 2.0577 - val_accuracy: 0.0909
# Epoch 78/100
# 2/2 [==============================] - 0s 130ms/step - loss: 1.1798 - accuracy: 0.4318 - val_loss: 2.0605 - val_accuracy: 0.0909
# Epoch 79/100
# 2/2 [==============================] - 0s 110ms/step - loss: 1.1789 - accuracy: 0.4318 - val_loss: 2.0651 - val_accuracy: 0.0909
# Epoch 80/100
# 2/2 [==============================] - 0s 125ms/step - loss: 1.1787 - accuracy: 0.4318 - val_loss: 2.0724 - val_accuracy: 0.0909
# Epoch 81/100
# 2/2 [==============================] - 0s 108ms/step - loss: 1.1768 - accuracy: 0.4318 - val_loss: 2.0860 - val_accuracy: 0.0909
# Epoch 82/100
# 2/2 [==============================] - 0s 301ms/step - loss: 1.1755 - accuracy: 0.4318 - val_loss: 2.1023 - val_accuracy: 0.0909
# Epoch 83/100
# 2/2 [==============================] - 0s 110ms/step - loss: 1.1738 - accuracy: 0.4318 - val_loss: 2.1173 - val_accuracy: 0.0909
# Epoch 84/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.1736 - accuracy: 0.4318 - val_loss: 2.1271 - val_accuracy: 0.0909
# Epoch 85/100
# 2/2 [==============================] - 0s 91ms/step - loss: 1.1719 - accuracy: 0.4318 - val_loss: 2.1265 - val_accuracy: 0.0909
# Epoch 86/100
# 2/2 [==============================] - 0s 123ms/step - loss: 1.1706 - accuracy: 0.4318 - val_loss: 2.1270 - val_accuracy: 0.0909
# Epoch 87/100
# 2/2 [==============================] - 0s 113ms/step - loss: 1.1701 - accuracy: 0.4318 - val_loss: 2.1293 - val_accuracy: 0.0909
# Epoch 88/100
# 2/2 [==============================] - 0s 123ms/step - loss: 1.1687 - accuracy: 0.4318 - val_loss: 2.1287 - val_accuracy: 0.0909
# Epoch 89/100
# 2/2 [==============================] - 0s 105ms/step - loss: 1.1692 - accuracy: 0.4545 - val_loss: 2.1287 - val_accuracy: 0.0909
# Epoch 90/100
# 2/2 [==============================] - 0s 172ms/step - loss: 1.1678 - accuracy: 0.4545 - val_loss: 2.1435 - val_accuracy: 0.0909
# Epoch 91/100
# 2/2 [==============================] - 0s 110ms/step - loss: 1.1654 - accuracy: 0.4545 - val_loss: 2.1709 - val_accuracy: 0.0909
# Epoch 92/100
# 2/2 [==============================] - 0s 101ms/step - loss: 1.1637 - accuracy: 0.4545 - val_loss: 2.1972 - val_accuracy: 0.0909
# Epoch 93/100
# 2/2 [==============================] - 0s 67ms/step - loss: 1.1631 - accuracy: 0.4318 - val_loss: 2.2232 - val_accuracy: 0.0909
# Epoch 94/100
# 2/2 [==============================] - 0s 160ms/step - loss: 1.1627 - accuracy: 0.4318 - val_loss: 2.2359 - val_accuracy: 0.0909
# Epoch 95/100
# 2/2 [==============================] - 0s 133ms/step - loss: 1.1609 - accuracy: 0.4318 - val_loss: 2.2337 - val_accuracy: 0.0909
# Epoch 96/100
# 2/2 [==============================] - 0s 132ms/step - loss: 1.1589 - accuracy: 0.4318 - val_loss: 2.2302 - val_accuracy: 0.0909
# Epoch 97/100
# 2/2 [==============================] - 0s 113ms/step - loss: 1.1567 - accuracy: 0.4545 - val_loss: 2.2313 - val_accuracy: 0.0909
# Epoch 98/100
# 2/2 [==============================] - 0s 83ms/step - loss: 1.1567 - accuracy: 0.4545 - val_loss: 2.2324 - val_accuracy: 0.0909
# Epoch 99/100
# 2/2 [==============================] - 0s 130ms/step - loss: 1.1547 - accuracy: 0.4545 - val_loss: 2.2405 - val_accuracy: 0.0909
# Epoch 100/100
# 2/2 [==============================] - 0s 219ms/step - loss: 1.1534 - accuracy: 0.4545 - val_loss: 2.2562 - val_accuracy: 0.0909
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic)
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1)
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2)
print("Predicted Labels - Combined AI:", predicted_labels_combined)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x15e3b3ba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 299ms/step
# Predicted Labels - Generic AI: ['Engineering']
# Predicted Labels - Parallel AI 1: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Parallel AI 2: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Combined AI: ['Civil Engineering']
