# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adamax', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=5, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=50)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Convert to Pandas DataFrames
output_df1 = pd.DataFrame(output_parallel_1)
output_df2 = pd.DataFrame(output_parallel_2)

# Save combined outputs to CSV
output_df1.to_csv("data_watch1.csv", index=False)
output_df2.to_csv("data_watch2.csv", index=False)

# Convert parallel AI 1 output to a single column (scaling down)
scaled_output_parallel_1 = output_parallel_1.argmax(axis=1)

# Convert parallel AI 2 output to a single column (scaling down)
scaled_output_parallel_2 = output_parallel_2.argmax(axis=1)

# Save scaled outputs along with labels to CSV
scaled_output_df1 = pd.DataFrame({'label': y_data_1_encoded[:min_rows], 'scaled_output': scaled_output_parallel_1})
scaled_output_df1.to_csv("scaled_output1.csv", index=False)

scaled_output_df2 = pd.DataFrame({'label': y_data_2_encoded[:min_rows], 'scaled_output': scaled_output_parallel_2})
scaled_output_df2.to_csv("scaled_output2.csv", index=False)

# Save the combined output to CSV
combined_output_df = pd.DataFrame(combined_output.numpy())
combined_output_df.to_csv("combined_output.csv", index=False)

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

# Load the third dataset for the final AI
data_3 = pd.read_csv("generated_data1.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using only the third dataset
model_combined.fit(X_data_3, y_data_3_encoded, epochs=100, validation_split=0.2)

# Save the output of the final AI to CSV
final_output = model_combined.predict(X_data_3)
final_output_df = pd.DataFrame(final_output)
final_output_df.to_csv("final_output.csv", index=False)  # Save final output to "final_output.csv"

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 1s/step - loss: 0.9326 - accuracy: 0.2500 - val_loss: 0.7389 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.7770 - accuracy: 0.5000 - val_loss: 0.8871 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6724 - accuracy: 0.7500 - val_loss: 1.0218 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 1/1 [==============================] - 0s 102ms/step - loss: 0.5969 - accuracy: 0.7500 - val_loss: 1.1464 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 0s 115ms/step - loss: 0.5411 - accuracy: 0.5000 - val_loss: 1.2592 - val_accuracy: 0.0000e+00
# Epoch 1/50
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 1s 11ms/step - loss: 1.3809 - accuracy: 0.3000
# Epoch 2/50
# 2/2 [==============================] - 0s 32ms/step - loss: 1.3379 - accuracy: 0.3833
# Epoch 3/50
# 2/2 [==============================] - 0s 46ms/step - loss: 1.3056 - accuracy: 0.4333
# Epoch 4/50
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2712 - accuracy: 0.5167
# Epoch 5/50
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2455 - accuracy: 0.5500
# Epoch 6/50
# 2/2 [==============================] - 0s 38ms/step - loss: 1.2175 - accuracy: 0.5667
# Epoch 7/50
# 2/2 [==============================] - 0s 15ms/step - loss: 1.1913 - accuracy: 0.5667
# Epoch 8/50
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1677 - accuracy: 0.5667
# Epoch 9/50
# 2/2 [==============================] - 0s 14ms/step - loss: 1.1427 - accuracy: 0.5667
# Epoch 10/50
# 2/2 [==============================] - 0s 13ms/step - loss: 1.1183 - accuracy: 0.5500
# Epoch 11/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.0937 - accuracy: 0.5667
# Epoch 12/50
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0694 - accuracy: 0.5667
# Epoch 13/50
# 2/2 [==============================] - 0s 13ms/step - loss: 1.0460 - accuracy: 0.5667
# Epoch 14/50
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0220 - accuracy: 0.5833
# Epoch 15/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9951 - accuracy: 0.6000
# Epoch 16/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.9692 - accuracy: 0.6333
# Epoch 17/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.9468 - accuracy: 0.6500
# Epoch 18/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.9207 - accuracy: 0.6500
# Epoch 19/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.8962 - accuracy: 0.7000
# Epoch 20/50
# 2/2 [==============================] - 0s 44ms/step - loss: 0.8707 - accuracy: 0.7667
# Epoch 21/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.8472 - accuracy: 0.7667
# Epoch 22/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.8234 - accuracy: 0.7667
# Epoch 23/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.8001 - accuracy: 0.7667
# Epoch 24/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7787 - accuracy: 0.7833
# Epoch 25/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7549 - accuracy: 0.8000
# Epoch 26/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7346 - accuracy: 0.8000
# Epoch 27/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.7136 - accuracy: 0.8000
# Epoch 28/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6924 - accuracy: 0.8000
# Epoch 29/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6738 - accuracy: 0.8167
# Epoch 30/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.6548 - accuracy: 0.8167
# Epoch 31/50
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6370 - accuracy: 0.8167
# Epoch 32/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6192 - accuracy: 0.8333
# Epoch 33/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6035 - accuracy: 0.8333
# Epoch 34/50
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5867 - accuracy: 0.8333
# Epoch 35/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5733 - accuracy: 0.8333
# Epoch 36/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5571 - accuracy: 0.8333
# Epoch 37/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.5425 - accuracy: 0.8333
# Epoch 38/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5286 - accuracy: 0.8333
# Epoch 39/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5152 - accuracy: 0.8333
# Epoch 40/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5024 - accuracy: 0.8333
# Epoch 41/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4904 - accuracy: 0.8500
# Epoch 42/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4768 - accuracy: 0.8500
# Epoch 43/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4644 - accuracy: 0.8500
# Epoch 44/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4519 - accuracy: 0.8667
# Epoch 45/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4406 - accuracy: 0.8833
# Epoch 46/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4296 - accuracy: 0.9000
# Epoch 47/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4188 - accuracy: 0.9000
# Epoch 48/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4083 - accuracy: 0.9000
# Epoch 49/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3977 - accuracy: 0.9000
# Epoch 50/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3876 - accuracy: 0.9000
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 7/7 [==============================] - 1s 4ms/step - loss: 1.4034 - accuracy: 0.0400
# Epoch 2/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3778 - accuracy: 0.2500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3613 - accuracy: 0.4550
# Epoch 4/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3487 - accuracy: 0.7550
# Epoch 5/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3336 - accuracy: 0.8500
# Epoch 6/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3188 - accuracy: 0.9600
# Epoch 7/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3042 - accuracy: 0.9500
# Epoch 8/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2859 - accuracy: 0.9750
# Epoch 9/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2675 - accuracy: 0.8550
# Epoch 10/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2467 - accuracy: 0.7700
# Epoch 11/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2267 - accuracy: 0.7300
# Epoch 12/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1995 - accuracy: 0.7850
# Epoch 13/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.1701 - accuracy: 0.8650
# Epoch 14/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1424 - accuracy: 0.9250
# Epoch 15/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.1063 - accuracy: 0.9850
# Epoch 16/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0742 - accuracy: 0.9800
# Epoch 17/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0312 - accuracy: 0.9400
# Epoch 18/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.9881 - accuracy: 0.9450
# Epoch 19/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9414 - accuracy: 0.9650
# Epoch 20/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8959 - accuracy: 0.9900
# Epoch 21/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8439 - accuracy: 0.9900
# Epoch 22/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7955 - accuracy: 0.9850
# Epoch 23/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7440 - accuracy: 0.9900
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6963 - accuracy: 0.9800
# Epoch 25/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6454 - accuracy: 0.9900
# Epoch 26/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5977 - accuracy: 0.9900
# Epoch 27/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5591 - accuracy: 0.9750
# Epoch 28/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5144 - accuracy: 0.9900
# Epoch 29/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4741 - accuracy: 0.9900
# Epoch 30/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4390 - accuracy: 0.9900
# Epoch 31/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4020 - accuracy: 0.9900
# Epoch 32/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3744 - accuracy: 0.9900
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3433 - accuracy: 0.9900
# Epoch 34/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3219 - accuracy: 0.9900
# Epoch 35/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.9900
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2753 - accuracy: 0.9850
# Epoch 37/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2581 - accuracy: 0.9900
# Epoch 38/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.9900
# Epoch 39/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2249 - accuracy: 0.9850
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2100 - accuracy: 0.9900
# Epoch 41/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1961 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1875 - accuracy: 0.9900
# Epoch 43/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1735 - accuracy: 0.9900
# Epoch 44/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1628 - accuracy: 0.9850
# Epoch 45/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1611 - accuracy: 0.9850
# Epoch 46/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1451 - accuracy: 0.9900
# Epoch 47/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1428 - accuracy: 0.9900
# Epoch 48/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1330 - accuracy: 0.9850
# Epoch 49/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1244 - accuracy: 0.9900
# Epoch 50/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1221 - accuracy: 0.9900
# 2/2 [==============================] - 0s 4ms/step
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 0s 2ms/step
# Epoch 1/100
# 2/2 [==============================] - 1s 289ms/step - loss: 1.3287 - accuracy: 0.3947 - val_loss: 1.5692 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.2910 - accuracy: 0.4474 - val_loss: 1.6430 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 0s 74ms/step - loss: 1.2617 - accuracy: 0.5263 - val_loss: 1.7159 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1.2348 - accuracy: 0.5526 - val_loss: 1.7906 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2097 - accuracy: 0.6842 - val_loss: 1.8671 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 2/2 [==============================] - 0s 49ms/step - loss: 1.1876 - accuracy: 0.6842 - val_loss: 1.9438 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1679 - accuracy: 0.6842 - val_loss: 2.0169 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 2/2 [==============================] - 0s 76ms/step - loss: 1.1463 - accuracy: 0.6842 - val_loss: 2.0843 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 2/2 [==============================] - 0s 56ms/step - loss: 1.1280 - accuracy: 0.6842 - val_loss: 2.1529 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1.1092 - accuracy: 0.6842 - val_loss: 2.2219 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 0s 60ms/step - loss: 1.0910 - accuracy: 0.6842 - val_loss: 2.2922 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 0s 52ms/step - loss: 1.0726 - accuracy: 0.7105 - val_loss: 2.3632 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1.0549 - accuracy: 0.7895 - val_loss: 2.4265 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0374 - accuracy: 0.8158 - val_loss: 2.4796 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1.0223 - accuracy: 0.8421 - val_loss: 2.5288 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0083 - accuracy: 0.8158 - val_loss: 2.5689 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.9907 - accuracy: 0.8421 - val_loss: 2.6095 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.9731 - accuracy: 0.8421 - val_loss: 2.6533 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.9564 - accuracy: 0.8158 - val_loss: 2.7004 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9397 - accuracy: 0.8158 - val_loss: 2.7484 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.9293 - accuracy: 0.7632 - val_loss: 2.7942 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.9177 - accuracy: 0.7105 - val_loss: 2.8358 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.9038 - accuracy: 0.6842 - val_loss: 2.8655 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.8878 - accuracy: 0.7105 - val_loss: 2.8798 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.8724 - accuracy: 0.7368 - val_loss: 2.8935 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.8559 - accuracy: 0.8158 - val_loss: 2.8975 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.8403 - accuracy: 0.8421 - val_loss: 2.8892 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.8249 - accuracy: 0.9211 - val_loss: 2.8776 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.8125 - accuracy: 0.8684 - val_loss: 2.8599 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8043 - accuracy: 0.8684 - val_loss: 2.8523 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.7937 - accuracy: 0.8684 - val_loss: 2.8446 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.7798 - accuracy: 0.8684 - val_loss: 2.8379 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 2/2 [==============================] - 0s 193ms/step - loss: 0.7642 - accuracy: 0.9474 - val_loss: 2.8372 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.7486 - accuracy: 0.8684 - val_loss: 2.8287 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.7380 - accuracy: 0.8684 - val_loss: 2.8090 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.7265 - accuracy: 0.8684 - val_loss: 2.7998 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.7139 - accuracy: 0.8684 - val_loss: 2.7953 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7023 - accuracy: 0.8684 - val_loss: 2.7854 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 2/2 [==============================] - 0s 107ms/step - loss: 0.6884 - accuracy: 0.8684 - val_loss: 2.7740 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.6733 - accuracy: 0.9211 - val_loss: 2.7792 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.6579 - accuracy: 0.9211 - val_loss: 2.7843 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.6474 - accuracy: 0.9211 - val_loss: 2.7725 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.6410 - accuracy: 0.9211 - val_loss: 2.7505 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6299 - accuracy: 0.9211 - val_loss: 2.7320 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.6182 - accuracy: 0.8684 - val_loss: 2.7235 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.6068 - accuracy: 0.8684 - val_loss: 2.7082 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5951 - accuracy: 0.9211 - val_loss: 2.6758 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.5829 - accuracy: 0.9474 - val_loss: 2.6475 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.5711 - accuracy: 0.9474 - val_loss: 2.6282 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.5609 - accuracy: 0.9474 - val_loss: 2.6068 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5516 - accuracy: 0.9474 - val_loss: 2.5800 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.5426 - accuracy: 0.9211 - val_loss: 2.5540 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5329 - accuracy: 0.9211 - val_loss: 2.5275 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.5220 - accuracy: 0.9211 - val_loss: 2.5169 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.5117 - accuracy: 0.9211 - val_loss: 2.5166 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 2/2 [==============================] - 0s 99ms/step - loss: 0.5034 - accuracy: 0.9211 - val_loss: 2.5234 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.4966 - accuracy: 0.8947 - val_loss: 2.5343 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 2/2 [==============================] - 0s 84ms/step - loss: 0.4850 - accuracy: 0.9211 - val_loss: 2.5529 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.4736 - accuracy: 0.9211 - val_loss: 2.5769 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4633 - accuracy: 0.9474 - val_loss: 2.5967 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4551 - accuracy: 0.9474 - val_loss: 2.6146 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4493 - accuracy: 0.9474 - val_loss: 2.6017 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.4431 - accuracy: 0.9474 - val_loss: 2.5669 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4325 - accuracy: 0.9474 - val_loss: 2.5297 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4234 - accuracy: 0.9474 - val_loss: 2.4999 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.4147 - accuracy: 0.9474 - val_loss: 2.4855 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4087 - accuracy: 0.9474 - val_loss: 2.5059 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.4050 - accuracy: 0.9474 - val_loss: 2.5509 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4067 - accuracy: 0.9474 - val_loss: 2.5840 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 2/2 [==============================] - 0s 178ms/step - loss: 0.4010 - accuracy: 0.9211 - val_loss: 2.5974 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.3892 - accuracy: 0.9474 - val_loss: 2.5962 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3767 - accuracy: 0.9474 - val_loss: 2.5763 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3673 - accuracy: 0.9474 - val_loss: 2.5556 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3589 - accuracy: 0.9474 - val_loss: 2.5318 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.3540 - accuracy: 0.9474 - val_loss: 2.4778 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3477 - accuracy: 0.9474 - val_loss: 2.4102 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.3408 - accuracy: 0.9474 - val_loss: 2.3530 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.3350 - accuracy: 0.9211 - val_loss: 2.3185 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.3294 - accuracy: 0.9211 - val_loss: 2.2955 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3211 - accuracy: 0.9474 - val_loss: 2.2941 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 2/2 [==============================] - 0s 100ms/step - loss: 0.3131 - accuracy: 0.9474 - val_loss: 2.3408 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.3106 - accuracy: 0.9474 - val_loss: 2.3864 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3113 - accuracy: 0.9474 - val_loss: 2.3648 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3021 - accuracy: 0.9474 - val_loss: 2.2965 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2935 - accuracy: 0.9474 - val_loss: 2.2233 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2872 - accuracy: 0.9474 - val_loss: 2.1722 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 2/2 [==============================] - 0s 209ms/step - loss: 0.2833 - accuracy: 0.9474 - val_loss: 2.1577 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.2823 - accuracy: 0.9474 - val_loss: 2.1781 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2803 - accuracy: 0.9474 - val_loss: 2.2187 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.2755 - accuracy: 0.9474 - val_loss: 2.2478 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2662 - accuracy: 0.9474 - val_loss: 2.2500 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2582 - accuracy: 0.9474 - val_loss: 2.2593 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.2542 - accuracy: 0.9474 - val_loss: 2.2930 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 2/2 [==============================] - 0s 100ms/step - loss: 0.2507 - accuracy: 0.9474 - val_loss: 2.3165 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2487 - accuracy: 0.9737 - val_loss: 2.3003 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 2/2 [==============================] - 0s 87ms/step - loss: 0.2458 - accuracy: 0.9737 - val_loss: 2.2634 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2406 - accuracy: 0.9737 - val_loss: 2.1769 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2365 - accuracy: 0.9737 - val_loss: 2.0945 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2305 - accuracy: 0.9737 - val_loss: 2.0519 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2260 - accuracy: 0.9737 - val_loss: 2.0455 - val_accuracy: 0.0000e+00
# 2/2 [==============================] - 0s 3ms/step
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
#input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
#input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]
input_data_parallel_1 = [0,0.66,0,0,0,0,0.25,0,0,0.5,0,0.25,0,0]
input_data_parallel_2 = [0.706181,0.604714,0.528406,0.557752,0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering', '1']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic)
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1)
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2)
print("Predicted Labels - Combined AI:", predicted_labels_combined)
# Out:
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 73ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 52
#      49 label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels
#      51 # Inverse transform the predictions to get the original labels
# ---> 52 predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
#      53 predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
#      54 predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:160, in LabelEncoder.inverse_transform(self, y)
#     158 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     159 if len(diff):
# --> 160     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     161 y = np.asarray(y)
#     162 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [1]
