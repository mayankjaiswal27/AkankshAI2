# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adamax', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=5, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=50)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Convert to Pandas DataFrames
output_df1 = pd.DataFrame(output_parallel_1)
output_df2 = pd.DataFrame(output_parallel_2)

# Save combined outputs to CSV
output_df1.to_csv("data_watch1.csv", index=False)
output_df2.to_csv("data_watch2.csv", index=False)

# Convert parallel AI 1 output to a single column (scaling down)
scaled_output_parallel_1 = output_parallel_1.argmax(axis=1)

# Convert parallel AI 2 output to a single column (scaling down)
scaled_output_parallel_2 = output_parallel_2.argmax(axis=1)

# Save scaled outputs along with labels to CSV
scaled_output_df1 = pd.DataFrame({'label': y_data_1_encoded[:min_rows], 'scaled_output': scaled_output_parallel_1})
scaled_output_df1.to_csv("scaled_output1.csv", index=False)

scaled_output_df2 = pd.DataFrame({'label': y_data_2_encoded[:min_rows], 'scaled_output': scaled_output_parallel_2})
scaled_output_df2.to_csv("scaled_output2.csv", index=False)

# Save the combined output to CSV
combined_output_df = pd.DataFrame(combined_output.numpy())
combined_output_df.to_csv("combined_output.csv", index=False)

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

# Load the third dataset for the final AI
data_3 = pd.read_csv("generated_data1.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using only the third dataset
model_combined.fit(X_data_3, y_data_3_encoded, epochs=100, validation_split=0.2)

# Save the output of the final AI to CSV
final_output = model_combined.predict(X_data_3)
final_output_df = pd.DataFrame(final_output)
final_output_df.to_csv("final_output.csv", index=False)  # Save final output to "final_output.csv"

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5798 - accuracy: 0.6667 - val_loss: 0.5293 - val_accuracy: 1.0000
# Epoch 2/5
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4328 - accuracy: 1.0000 - val_loss: 0.4024 - val_accuracy: 1.0000
# Epoch 3/5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.3306 - accuracy: 1.0000 - val_loss: 0.3091 - val_accuracy: 1.0000
# Epoch 4/5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.2580 - accuracy: 1.0000 - val_loss: 0.2398 - val_accuracy: 1.0000
# Epoch 5/5
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2056 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 1.0000
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 2/2 [==============================] - 1s 9ms/step - loss: 1.4299 - accuracy: 0.1500
# Epoch 2/50
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3819 - accuracy: 0.2167
# Epoch 3/50
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3396 - accuracy: 0.2833
# Epoch 4/50
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3120 - accuracy: 0.4167
# Epoch 5/50
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2823 - accuracy: 0.4833
# Epoch 6/50
# 2/2 [==============================] - 0s 36ms/step - loss: 1.2551 - accuracy: 0.4833
# Epoch 7/50
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2327 - accuracy: 0.4833
# Epoch 8/50
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2116 - accuracy: 0.5000
# Epoch 9/50
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1927 - accuracy: 0.5000
# Epoch 10/50
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1698 - accuracy: 0.5333
# Epoch 11/50
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1487 - accuracy: 0.5333
# Epoch 12/50
# 2/2 [==============================] - 0s 12ms/step - loss: 1.1262 - accuracy: 0.5333
# Epoch 13/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1064 - accuracy: 0.5667
# Epoch 14/50
# 2/2 [==============================] - 0s 15ms/step - loss: 1.0824 - accuracy: 0.5667
# Epoch 15/50
# 2/2 [==============================] - 0s 14ms/step - loss: 1.0599 - accuracy: 0.5833
# Epoch 16/50
# 2/2 [==============================] - 0s 11ms/step - loss: 1.0367 - accuracy: 0.6333
# Epoch 17/50
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0131 - accuracy: 0.6667
# Epoch 18/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9888 - accuracy: 0.6833
# Epoch 19/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9647 - accuracy: 0.6833
# Epoch 20/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9393 - accuracy: 0.7000
# Epoch 21/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9160 - accuracy: 0.7167
# Epoch 22/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8938 - accuracy: 0.7667
# Epoch 23/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8688 - accuracy: 0.7667
# Epoch 24/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8474 - accuracy: 0.7833
# Epoch 25/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8237 - accuracy: 0.8000
# Epoch 26/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.8002 - accuracy: 0.8000
# Epoch 27/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7778 - accuracy: 0.8167
# Epoch 28/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7566 - accuracy: 0.8167
# Epoch 29/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7357 - accuracy: 0.8167
# Epoch 30/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.7146 - accuracy: 0.8000
# Epoch 31/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6948 - accuracy: 0.8000
# Epoch 32/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6770 - accuracy: 0.7833
# Epoch 33/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6558 - accuracy: 0.7833
# Epoch 34/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6390 - accuracy: 0.7833
# Epoch 35/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6211 - accuracy: 0.7833
# Epoch 36/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6055 - accuracy: 0.8167
# Epoch 37/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5890 - accuracy: 0.8167
# Epoch 38/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5749 - accuracy: 0.8500
# Epoch 39/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5596 - accuracy: 0.8500
# Epoch 40/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5463 - accuracy: 0.8667
# Epoch 41/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5333 - accuracy: 0.8667
# Epoch 42/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5210 - accuracy: 0.8833
# Epoch 43/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5090 - accuracy: 0.8833
# Epoch 44/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4972 - accuracy: 0.8833
# Epoch 45/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4870 - accuracy: 0.8833
# Epoch 46/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4766 - accuracy: 0.8833
# Epoch 47/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4656 - accuracy: 0.8833
# Epoch 48/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4545 - accuracy: 0.9000
# Epoch 49/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4467 - accuracy: 0.9000
# Epoch 50/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4366 - accuracy: 0.9000
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 7/7 [==============================] - 2s 3ms/step - loss: 1.3821 - accuracy: 0.1950
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3575 - accuracy: 0.2550
# Epoch 3/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.3403 - accuracy: 0.5850
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3160 - accuracy: 0.7050
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2956 - accuracy: 0.6300
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2700 - accuracy: 0.8250
# Epoch 7/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2434 - accuracy: 0.8900
# Epoch 8/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2162 - accuracy: 0.8400
# Epoch 9/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1815 - accuracy: 0.9400
# Epoch 10/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1491 - accuracy: 0.9500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1137 - accuracy: 0.7850
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0742 - accuracy: 0.8350
# Epoch 13/50
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0335 - accuracy: 0.9850
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9919 - accuracy: 0.9850
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9476 - accuracy: 0.9800
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9055 - accuracy: 0.9900
# Epoch 17/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8588 - accuracy: 0.9750
# Epoch 18/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8094 - accuracy: 0.9850
# Epoch 19/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7667 - accuracy: 0.9750
# Epoch 20/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7172 - accuracy: 0.9850
# Epoch 21/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6784 - accuracy: 0.9850
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6343 - accuracy: 0.9800
# Epoch 23/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5941 - accuracy: 0.9850
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5560 - accuracy: 0.9850
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5164 - accuracy: 0.9850
# Epoch 26/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4832 - accuracy: 0.9850
# Epoch 27/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4499 - accuracy: 0.9800
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.9800
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3934 - accuracy: 0.9850
# Epoch 30/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3624 - accuracy: 0.9900
# Epoch 31/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3402 - accuracy: 0.9850
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3176 - accuracy: 0.9850
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2946 - accuracy: 0.9800
# Epoch 34/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2783 - accuracy: 0.9850
# Epoch 35/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2592 - accuracy: 0.9900
# Epoch 36/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2424 - accuracy: 0.9900
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2280 - accuracy: 0.9850
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.9900
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2029 - accuracy: 0.9850
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1908 - accuracy: 0.9850
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1803 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 0.9850
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1632 - accuracy: 0.9850
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1538 - accuracy: 0.9850
# Epoch 45/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1461 - accuracy: 0.9900
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9900
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1323 - accuracy: 0.9850
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1273 - accuracy: 0.9900
# Epoch 49/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1218 - accuracy: 0.9850
# Epoch 50/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1166 - accuracy: 0.9900
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 2ms/step
# Epoch 1/100
# 2/2 [==============================] - 2s 480ms/step - loss: 1.4305 - accuracy: 0.1579 - val_loss: 1.4243 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 0s 80ms/step - loss: 1.3668 - accuracy: 0.2368 - val_loss: 1.5736 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1.3202 - accuracy: 0.3421 - val_loss: 1.7168 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.2839 - accuracy: 0.3684 - val_loss: 1.8517 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 2/2 [==============================] - 0s 57ms/step - loss: 1.2548 - accuracy: 0.4211 - val_loss: 1.9754 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 2/2 [==============================] - 0s 62ms/step - loss: 1.2325 - accuracy: 0.4211 - val_loss: 2.0827 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1.2102 - accuracy: 0.6053 - val_loss: 2.1705 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 2/2 [==============================] - 0s 59ms/step - loss: 1.1980 - accuracy: 0.5789 - val_loss: 2.2528 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 2/2 [==============================] - 0s 202ms/step - loss: 1.1823 - accuracy: 0.5789 - val_loss: 2.3268 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 0s 69ms/step - loss: 1.1669 - accuracy: 0.6579 - val_loss: 2.3958 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.1519 - accuracy: 0.7105 - val_loss: 2.4617 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1.1389 - accuracy: 0.7632 - val_loss: 2.5248 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.1259 - accuracy: 0.7632 - val_loss: 2.5845 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 0s 48ms/step - loss: 1.1137 - accuracy: 0.7895 - val_loss: 2.6277 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 0s 61ms/step - loss: 1.1019 - accuracy: 0.7895 - val_loss: 2.6541 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0889 - accuracy: 0.7632 - val_loss: 2.6840 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 2/2 [==============================] - 0s 55ms/step - loss: 1.0804 - accuracy: 0.7895 - val_loss: 2.7138 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 0s 82ms/step - loss: 1.0673 - accuracy: 0.7632 - val_loss: 2.7412 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 0s 61ms/step - loss: 1.0560 - accuracy: 0.7632 - val_loss: 2.7552 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 2/2 [==============================] - 0s 58ms/step - loss: 1.0439 - accuracy: 0.7632 - val_loss: 2.7543 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0325 - accuracy: 0.8421 - val_loss: 2.7594 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0201 - accuracy: 0.8158 - val_loss: 2.7683 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 0s 74ms/step - loss: 1.0086 - accuracy: 0.7895 - val_loss: 2.7810 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.9977 - accuracy: 0.7895 - val_loss: 2.7982 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 2/2 [==============================] - 0s 89ms/step - loss: 0.9889 - accuracy: 0.7895 - val_loss: 2.7964 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.9743 - accuracy: 0.7895 - val_loss: 2.7701 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.9590 - accuracy: 0.7895 - val_loss: 2.7575 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9439 - accuracy: 0.8158 - val_loss: 2.7576 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.9293 - accuracy: 0.8684 - val_loss: 2.7689 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.9186 - accuracy: 0.7895 - val_loss: 2.7858 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.9086 - accuracy: 0.7632 - val_loss: 2.8069 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.8990 - accuracy: 0.7368 - val_loss: 2.8232 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.8887 - accuracy: 0.7632 - val_loss: 2.8317 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.8742 - accuracy: 0.7632 - val_loss: 2.8356 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8588 - accuracy: 0.7895 - val_loss: 2.8185 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.8420 - accuracy: 0.7895 - val_loss: 2.7870 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.8314 - accuracy: 0.8421 - val_loss: 2.7708 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.8142 - accuracy: 0.8947 - val_loss: 2.7708 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.8030 - accuracy: 0.8158 - val_loss: 2.7722 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7867 - accuracy: 0.8684 - val_loss: 2.7679 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 2/2 [==============================] - 0s 101ms/step - loss: 0.7735 - accuracy: 0.8947 - val_loss: 2.7640 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.7611 - accuracy: 0.8421 - val_loss: 2.7492 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7508 - accuracy: 0.8158 - val_loss: 2.7229 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.7410 - accuracy: 0.7895 - val_loss: 2.7118 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.7309 - accuracy: 0.7632 - val_loss: 2.7131 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7182 - accuracy: 0.7895 - val_loss: 2.7048 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.7017 - accuracy: 0.8158 - val_loss: 2.6705 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6867 - accuracy: 0.8684 - val_loss: 2.6402 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6728 - accuracy: 0.8684 - val_loss: 2.6321 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6635 - accuracy: 0.8421 - val_loss: 2.6230 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 2/2 [==============================] - 0s 88ms/step - loss: 0.6513 - accuracy: 0.8684 - val_loss: 2.6074 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6411 - accuracy: 0.8684 - val_loss: 2.5910 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6287 - accuracy: 0.8684 - val_loss: 2.5747 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.6161 - accuracy: 0.8684 - val_loss: 2.5802 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6065 - accuracy: 0.8947 - val_loss: 2.5948 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5994 - accuracy: 0.9211 - val_loss: 2.5983 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 2/2 [==============================] - 0s 465ms/step - loss: 0.5917 - accuracy: 0.8947 - val_loss: 2.5897 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5814 - accuracy: 0.8947 - val_loss: 2.5688 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 2/2 [==============================] - 0s 286ms/step - loss: 0.5702 - accuracy: 0.8947 - val_loss: 2.5538 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 2/2 [==============================] - 0s 209ms/step - loss: 0.5582 - accuracy: 0.8684 - val_loss: 2.5612 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.5460 - accuracy: 0.8947 - val_loss: 2.5897 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5363 - accuracy: 0.8947 - val_loss: 2.6240 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 2/2 [==============================] - 0s 218ms/step - loss: 0.5342 - accuracy: 0.8947 - val_loss: 2.6336 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5255 - accuracy: 0.8947 - val_loss: 2.5939 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.5179 - accuracy: 0.8947 - val_loss: 2.5512 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.5069 - accuracy: 0.8947 - val_loss: 2.5483 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4978 - accuracy: 0.8947 - val_loss: 2.5685 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.4896 - accuracy: 0.8947 - val_loss: 2.5805 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4834 - accuracy: 0.8947 - val_loss: 2.5771 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.4784 - accuracy: 0.9211 - val_loss: 2.5842 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4704 - accuracy: 0.9474 - val_loss: 2.5649 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4607 - accuracy: 0.9474 - val_loss: 2.5360 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4483 - accuracy: 0.9474 - val_loss: 2.5194 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.4398 - accuracy: 0.9474 - val_loss: 2.5010 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 2/2 [==============================] - 0s 336ms/step - loss: 0.4320 - accuracy: 0.9211 - val_loss: 2.4974 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.4261 - accuracy: 0.8947 - val_loss: 2.5133 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.4241 - accuracy: 0.8947 - val_loss: 2.5234 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 2/2 [==============================] - 0s 212ms/step - loss: 0.4199 - accuracy: 0.8947 - val_loss: 2.5185 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4140 - accuracy: 0.8947 - val_loss: 2.5337 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4049 - accuracy: 0.8947 - val_loss: 2.5688 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 2/2 [==============================] - 0s 228ms/step - loss: 0.3950 - accuracy: 0.8947 - val_loss: 2.6138 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3861 - accuracy: 0.9474 - val_loss: 2.6411 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.3820 - accuracy: 0.9474 - val_loss: 2.6414 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.3766 - accuracy: 0.9474 - val_loss: 2.5917 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.3757 - accuracy: 0.9474 - val_loss: 2.5176 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.3686 - accuracy: 0.9474 - val_loss: 2.4384 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.3599 - accuracy: 0.9474 - val_loss: 2.3609 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 2/2 [==============================] - 0s 102ms/step - loss: 0.3498 - accuracy: 0.9474 - val_loss: 2.3058 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 2/2 [==============================] - 0s 196ms/step - loss: 0.3434 - accuracy: 0.9474 - val_loss: 2.2592 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 2/2 [==============================] - 0s 133ms/step - loss: 0.3406 - accuracy: 0.8947 - val_loss: 2.1926 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3410 - accuracy: 0.8947 - val_loss: 2.1264 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.3440 - accuracy: 0.8947 - val_loss: 2.1132 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3410 - accuracy: 0.8947 - val_loss: 2.2030 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.3254 - accuracy: 0.8947 - val_loss: 2.3791 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 2/2 [==============================] - 0s 180ms/step - loss: 0.3115 - accuracy: 0.9474 - val_loss: 2.5775 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 2/2 [==============================] - 0s 124ms/step - loss: 0.3131 - accuracy: 0.9474 - val_loss: 2.7358 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.3185 - accuracy: 0.9474 - val_loss: 2.7806 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 2/2 [==============================] - 0s 96ms/step - loss: 0.3220 - accuracy: 0.9474 - val_loss: 2.7320 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.3168 - accuracy: 0.9474 - val_loss: 2.6027 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.2997 - accuracy: 0.9474 - val_loss: 2.4018 - val_accuracy: 0.0000e+00
# 2/2 [==============================] - 0s 6ms/step
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering', '1']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic)
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1)
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2)
print("Predicted Labels - Combined AI:", predicted_labels_combined)

# Assuming you have a dataset like this
# Note: This is just a sample, replace it with your actual dataset
college_exam_data = {
    'Computer Science and Engineering (including specializations) / Information Technology': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'IIT Kharagpur', 'Bits Pilani'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']
    },
    'Electronics and Communication Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'Bits Pilani', 'NIT Trichy'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']
    },
    'Mechanical Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Roorky', 'IIT Guwahati', 'BITS Hyderabad'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']

    },
    'Civil Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'IIT Kanpur', 'IIT BHU'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']

    }
}

def get_college_exam_info(predicted_label):
    return college_exam_data.get(predicted_label, {'colleges': [], 'exams': []})

# Example usage:
predicted_label_combined = predicted_labels_combined[0]  # Assuming it's a single prediction
info = get_college_exam_info(predicted_label_combined)

print(f"Prediction: {predicted_label_combined}")
print("Colleges:")
for college in info['colleges']:
    print(f"  - {college}")
print("Entrance Exams:")
for exam in info['exams']:
    print(f"  - {exam}")
print("Resources:")
for res in info['resources']:
    print(f"  - {res}")
# Out:
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 128ms/step
# Predicted Labels - Generic AI: ['Engineering']
# Predicted Labels - Parallel AI 1: ['Electronics and Communication Engineering']
# Predicted Labels - Parallel AI 2: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Combined AI: ['Computer Science and Engineering (including specializations) / Information Technology']
# Prediction: Computer Science and Engineering (including specializations) / Information Technology
# Colleges:
#   - IIT Madras
#   - IIT Delhi
#   - IIT Bombay
#   - IIT Kharagpur
#   - Bits Pilani
# Entrance Exams:
#   - JEE Mains
#   - JEE Advance
#   - BITSAT
# Resources:
#   - Geeks for Geeks: https://www.geeksforgeeks.org/
#   - CodeChef: https://www.codechef.com/
#   - Coursera: https://www.coursera.org/en-IN
