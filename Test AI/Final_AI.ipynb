# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adamax', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=5, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=50)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Convert to Pandas DataFrames
output_df1 = pd.DataFrame(output_parallel_1)
output_df2 = pd.DataFrame(output_parallel_2)

# Save combined outputs to CSV
output_df1.to_csv("data_watch1.csv", index=False)
output_df2.to_csv("data_watch2.csv", index=False)

# Convert parallel AI 1 output to a single column (scaling down)
scaled_output_parallel_1 = output_parallel_1.argmax(axis=1)

# Convert parallel AI 2 output to a single column (scaling down)
scaled_output_parallel_2 = output_parallel_2.argmax(axis=1)

# Save scaled outputs along with labels to CSV
scaled_output_df1 = pd.DataFrame({'label': y_data_1_encoded[:min_rows], 'scaled_output': scaled_output_parallel_1})
scaled_output_df1.to_csv("scaled_output1.csv", index=False)

scaled_output_df2 = pd.DataFrame({'label': y_data_2_encoded[:min_rows], 'scaled_output': scaled_output_parallel_2})
scaled_output_df2.to_csv("scaled_output2.csv", index=False)

# Save the combined output to CSV
combined_output_df = pd.DataFrame(combined_output.numpy())
combined_output_df.to_csv("combined_output.csv", index=False)

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

# Load the third dataset for the final AI
data_3 = pd.read_csv("generated_data1.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using only the third dataset
model_combined.fit(X_data_3, y_data_3_encoded, epochs=100, validation_split=0.2)

# Save the output of the final AI to CSV
final_output = model_combined.predict(X_data_3)
final_output_df = pd.DataFrame(final_output)
final_output_df.to_csv("final_output.csv", index=False)  # Save final output to "final_output.csv"

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/5
# 1/1 [==============================] - 4s 4s/step - loss: 0.8670 - accuracy: 0.0000e+00 - val_loss: 0.7792 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.7598 - accuracy: 0.2500 - val_loss: 0.7631 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 1/1 [==============================] - 0s 100ms/step - loss: 0.6802 - accuracy: 0.5000 - val_loss: 0.7547 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6179 - accuracy: 0.7500 - val_loss: 0.7505 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.5661 - accuracy: 0.7500 - val_loss: 0.7430 - val_accuracy: 0.0000e+00
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 2/2 [==============================] - 3s 25ms/step - loss: 1.3715 - accuracy: 0.4167
# Epoch 2/50
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3377 - accuracy: 0.4500
# Epoch 3/50
# 2/2 [==============================] - 0s 43ms/step - loss: 1.3094 - accuracy: 0.4333
# Epoch 4/50
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2829 - accuracy: 0.4333
# Epoch 5/50
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2584 - accuracy: 0.4500
# Epoch 6/50
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2337 - accuracy: 0.5000
# Epoch 7/50
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2111 - accuracy: 0.5167
# Epoch 8/50
# 2/2 [==============================] - 0s 27ms/step - loss: 1.1867 - accuracy: 0.5333
# Epoch 9/50
# 2/2 [==============================] - 0s 31ms/step - loss: 1.1634 - accuracy: 0.5500
# Epoch 10/50
# 2/2 [==============================] - 0s 13ms/step - loss: 1.1392 - accuracy: 0.5667
# Epoch 11/50
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1151 - accuracy: 0.6167
# Epoch 12/50
# 2/2 [==============================] - 0s 17ms/step - loss: 1.0902 - accuracy: 0.6333
# Epoch 13/50
# 2/2 [==============================] - 0s 12ms/step - loss: 1.0648 - accuracy: 0.6333
# Epoch 14/50
# 2/2 [==============================] - 0s 19ms/step - loss: 1.0399 - accuracy: 0.6833
# Epoch 15/50
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0148 - accuracy: 0.6833
# Epoch 16/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9901 - accuracy: 0.7000
# Epoch 17/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.9640 - accuracy: 0.6833
# Epoch 18/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.9388 - accuracy: 0.7333
# Epoch 19/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.9125 - accuracy: 0.7500
# Epoch 20/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.8869 - accuracy: 0.7500
# Epoch 21/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8631 - accuracy: 0.7667
# Epoch 22/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.8363 - accuracy: 0.7833
# Epoch 23/50
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8115 - accuracy: 0.7833
# Epoch 24/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7868 - accuracy: 0.7833
# Epoch 25/50
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7628 - accuracy: 0.7833
# Epoch 26/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7412 - accuracy: 0.7833
# Epoch 27/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.7193 - accuracy: 0.7833
# Epoch 28/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.6968 - accuracy: 0.8167
# Epoch 29/50
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6748 - accuracy: 0.8500
# Epoch 30/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6558 - accuracy: 0.8667
# Epoch 31/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6375 - accuracy: 0.8667
# Epoch 32/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6189 - accuracy: 0.8667
# Epoch 33/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6016 - accuracy: 0.8667
# Epoch 34/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5844 - accuracy: 0.8500
# Epoch 35/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5680 - accuracy: 0.8500
# Epoch 36/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.5533 - accuracy: 0.8667
# Epoch 37/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5398 - accuracy: 0.8667
# Epoch 38/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5243 - accuracy: 0.8667
# Epoch 39/50
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5111 - accuracy: 0.8667
# Epoch 40/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4987 - accuracy: 0.8667
# Epoch 41/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4868 - accuracy: 0.8667
# Epoch 42/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4753 - accuracy: 0.8667
# Epoch 43/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4650 - accuracy: 0.8667
# Epoch 44/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.4521 - accuracy: 0.8833
# Epoch 45/50
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4415 - accuracy: 0.8833
# Epoch 46/50
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4315 - accuracy: 0.8833
# Epoch 47/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4220 - accuracy: 0.8833
# Epoch 48/50
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4128 - accuracy: 0.8833
# Epoch 49/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4035 - accuracy: 0.9000
# Epoch 50/50
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3944 - accuracy: 0.9000
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 1/50
# 7/7 [==============================] - 3s 11ms/step - loss: 1.3779 - accuracy: 0.3550
# Epoch 2/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3432 - accuracy: 0.3850
# Epoch 3/50
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3145 - accuracy: 0.6950
# Epoch 4/50
# 7/7 [==============================] - 0s 12ms/step - loss: 1.2855 - accuracy: 0.8000
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2562 - accuracy: 0.7300
# Epoch 6/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.2256 - accuracy: 0.8800
# Epoch 7/50
# 7/7 [==============================] - 0s 29ms/step - loss: 1.1903 - accuracy: 0.9750
# Epoch 8/50
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1540 - accuracy: 0.9700
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1156 - accuracy: 0.9800
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0740 - accuracy: 0.9650
# Epoch 11/50
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0277 - accuracy: 0.8900
# Epoch 12/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.9826 - accuracy: 0.8150
# Epoch 13/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.9327 - accuracy: 0.9100
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8813 - accuracy: 0.9700
# Epoch 15/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.8263 - accuracy: 0.9250
# Epoch 16/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7747 - accuracy: 0.9300
# Epoch 17/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7250 - accuracy: 0.9300
# Epoch 18/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6735 - accuracy: 0.9150
# Epoch 19/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6282 - accuracy: 0.9650
# Epoch 20/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5826 - accuracy: 0.9850
# Epoch 21/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5450 - accuracy: 0.9900
# Epoch 22/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5049 - accuracy: 0.9900
# Epoch 23/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4732 - accuracy: 0.9700
# Epoch 24/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4408 - accuracy: 0.9600
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4078 - accuracy: 0.9900
# Epoch 26/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3839 - accuracy: 0.9850
# Epoch 27/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3630 - accuracy: 0.9900
# Epoch 28/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3355 - accuracy: 0.9900
# Epoch 29/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3160 - accuracy: 0.9850
# Epoch 30/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2959 - accuracy: 0.9900
# Epoch 31/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2774 - accuracy: 0.9900
# Epoch 32/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2678 - accuracy: 0.9800
# Epoch 33/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2479 - accuracy: 0.9850
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2331 - accuracy: 0.9900
# Epoch 35/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2318 - accuracy: 0.9700
# Epoch 36/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2073 - accuracy: 0.9900
# Epoch 37/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1961 - accuracy: 0.9850
# Epoch 38/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1904 - accuracy: 0.9850
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1812 - accuracy: 0.9800
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9850
# Epoch 41/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1587 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1497 - accuracy: 0.9900
# Epoch 43/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1422 - accuracy: 0.9900
# Epoch 44/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1390 - accuracy: 0.9900
# Epoch 45/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9900
# Epoch 46/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1256 - accuracy: 0.9900
# Epoch 47/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1194 - accuracy: 0.9900
# Epoch 48/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1208 - accuracy: 0.9850
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1152 - accuracy: 0.9900
# Epoch 50/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1119 - accuracy: 0.9900
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 4ms/step
# Epoch 1/100
# 2/2 [==============================] - 3s 822ms/step - loss: 1.4509 - accuracy: 0.0526 - val_loss: 1.3308 - val_accuracy: 0.2000
# Epoch 2/100
# 2/2 [==============================] - 0s 78ms/step - loss: 1.4040 - accuracy: 0.2632 - val_loss: 1.3748 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 0s 106ms/step - loss: 1.3623 - accuracy: 0.3947 - val_loss: 1.4140 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 0s 84ms/step - loss: 1.3312 - accuracy: 0.5263 - val_loss: 1.4555 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 2/2 [==============================] - 0s 102ms/step - loss: 1.2971 - accuracy: 0.6579 - val_loss: 1.4985 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 2/2 [==============================] - 0s 122ms/step - loss: 1.2688 - accuracy: 0.6579 - val_loss: 1.5441 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 2/2 [==============================] - 0s 145ms/step - loss: 1.2386 - accuracy: 0.6842 - val_loss: 1.5917 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 2/2 [==============================] - 0s 179ms/step - loss: 1.2093 - accuracy: 0.6316 - val_loss: 1.6435 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 2/2 [==============================] - 0s 85ms/step - loss: 1.1827 - accuracy: 0.6842 - val_loss: 1.6983 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 0s 173ms/step - loss: 1.1531 - accuracy: 0.7368 - val_loss: 1.7545 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 0s 96ms/step - loss: 1.1261 - accuracy: 0.7895 - val_loss: 1.8139 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 0s 100ms/step - loss: 1.0996 - accuracy: 0.7895 - val_loss: 1.8751 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 0s 68ms/step - loss: 1.0739 - accuracy: 0.7895 - val_loss: 1.9350 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 0s 123ms/step - loss: 1.0467 - accuracy: 0.7895 - val_loss: 1.9926 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 0s 309ms/step - loss: 1.0243 - accuracy: 0.7895 - val_loss: 2.0544 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 2/2 [==============================] - 0s 151ms/step - loss: 1.0011 - accuracy: 0.7895 - val_loss: 2.1182 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.9783 - accuracy: 0.7895 - val_loss: 2.1846 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.9578 - accuracy: 0.7895 - val_loss: 2.2477 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.9372 - accuracy: 0.7895 - val_loss: 2.3028 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.9160 - accuracy: 0.7895 - val_loss: 2.3589 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.8943 - accuracy: 0.7632 - val_loss: 2.4163 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.8749 - accuracy: 0.7632 - val_loss: 2.4727 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.8583 - accuracy: 0.7632 - val_loss: 2.5057 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.8350 - accuracy: 0.8158 - val_loss: 2.5024 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 2/2 [==============================] - 0s 86ms/step - loss: 0.8150 - accuracy: 0.8684 - val_loss: 2.4878 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 0s 106ms/step - loss: 0.7965 - accuracy: 0.8684 - val_loss: 2.4725 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 2/2 [==============================] - 0s 145ms/step - loss: 0.7787 - accuracy: 0.9211 - val_loss: 2.4672 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.7631 - accuracy: 0.9211 - val_loss: 2.4673 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.7437 - accuracy: 0.9211 - val_loss: 2.4624 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 2/2 [==============================] - 0s 147ms/step - loss: 0.7245 - accuracy: 0.9211 - val_loss: 2.4540 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.7077 - accuracy: 0.8947 - val_loss: 2.4556 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.6929 - accuracy: 0.8421 - val_loss: 2.4646 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.6802 - accuracy: 0.7895 - val_loss: 2.4795 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 2/2 [==============================] - 0s 260ms/step - loss: 0.6700 - accuracy: 0.7895 - val_loss: 2.4918 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.6549 - accuracy: 0.7895 - val_loss: 2.4896 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.6372 - accuracy: 0.7895 - val_loss: 2.4866 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6177 - accuracy: 0.8421 - val_loss: 2.4986 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6026 - accuracy: 0.8947 - val_loss: 2.5212 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5864 - accuracy: 0.8947 - val_loss: 2.5528 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5766 - accuracy: 0.8947 - val_loss: 2.5914 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5639 - accuracy: 0.9211 - val_loss: 2.6191 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.5510 - accuracy: 0.9211 - val_loss: 2.6280 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.5400 - accuracy: 0.9474 - val_loss: 2.6151 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5281 - accuracy: 0.9474 - val_loss: 2.5901 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5191 - accuracy: 0.9474 - val_loss: 2.5646 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.5075 - accuracy: 0.9474 - val_loss: 2.5444 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4927 - accuracy: 0.9474 - val_loss: 2.5230 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4792 - accuracy: 0.9474 - val_loss: 2.4905 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4675 - accuracy: 0.9474 - val_loss: 2.4559 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.4573 - accuracy: 0.9211 - val_loss: 2.4404 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 2/2 [==============================] - 0s 99ms/step - loss: 0.4464 - accuracy: 0.9474 - val_loss: 2.4314 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4345 - accuracy: 0.9474 - val_loss: 2.4370 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.4271 - accuracy: 0.9474 - val_loss: 2.4438 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4176 - accuracy: 0.9474 - val_loss: 2.4355 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 2/2 [==============================] - 0s 69ms/step - loss: 0.4084 - accuracy: 0.9474 - val_loss: 2.4437 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.4003 - accuracy: 0.9474 - val_loss: 2.4687 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3918 - accuracy: 0.9474 - val_loss: 2.4973 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.3857 - accuracy: 0.9474 - val_loss: 2.5251 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.3795 - accuracy: 0.9474 - val_loss: 2.5471 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3707 - accuracy: 0.9474 - val_loss: 2.5585 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 2/2 [==============================] - 0s 90ms/step - loss: 0.3621 - accuracy: 0.9474 - val_loss: 2.5742 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 2/2 [==============================] - 0s 51ms/step - loss: 0.3518 - accuracy: 0.9474 - val_loss: 2.5894 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3465 - accuracy: 0.9474 - val_loss: 2.5824 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3458 - accuracy: 0.9474 - val_loss: 2.5402 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3411 - accuracy: 0.9474 - val_loss: 2.4789 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3330 - accuracy: 0.9474 - val_loss: 2.3843 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.3238 - accuracy: 0.9474 - val_loss: 2.2941 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.3119 - accuracy: 0.9474 - val_loss: 2.2383 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.3032 - accuracy: 0.9474 - val_loss: 2.2159 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 2/2 [==============================] - 0s 222ms/step - loss: 0.2948 - accuracy: 0.9474 - val_loss: 2.2046 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.2894 - accuracy: 0.9474 - val_loss: 2.1926 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2842 - accuracy: 0.9474 - val_loss: 2.1845 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2789 - accuracy: 0.9474 - val_loss: 2.1792 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.2723 - accuracy: 0.9474 - val_loss: 2.1707 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2648 - accuracy: 0.9474 - val_loss: 2.1330 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 2/2 [==============================] - 0s 92ms/step - loss: 0.2598 - accuracy: 0.9474 - val_loss: 2.0853 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2597 - accuracy: 0.9737 - val_loss: 2.0746 - val_accuracy: 0.1000
# Epoch 78/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2598 - accuracy: 0.9737 - val_loss: 2.1273 - val_accuracy: 0.1000
# Epoch 79/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.2525 - accuracy: 0.9737 - val_loss: 2.2199 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2473 - accuracy: 0.9737 - val_loss: 2.2794 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 2/2 [==============================] - 0s 104ms/step - loss: 0.2397 - accuracy: 0.9737 - val_loss: 2.2783 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 2/2 [==============================] - 0s 68ms/step - loss: 0.2333 - accuracy: 0.9474 - val_loss: 2.2775 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 2/2 [==============================] - 0s 95ms/step - loss: 0.2296 - accuracy: 0.9474 - val_loss: 2.2835 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.2283 - accuracy: 0.9474 - val_loss: 2.3255 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.2225 - accuracy: 0.9474 - val_loss: 2.3846 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.2143 - accuracy: 0.9474 - val_loss: 2.4246 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2095 - accuracy: 0.9474 - val_loss: 2.4533 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 2/2 [==============================] - 0s 98ms/step - loss: 0.2039 - accuracy: 0.9474 - val_loss: 2.4807 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1998 - accuracy: 0.9474 - val_loss: 2.4619 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1964 - accuracy: 0.9737 - val_loss: 2.4027 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 2/2 [==============================] - 0s 99ms/step - loss: 0.1919 - accuracy: 0.9737 - val_loss: 2.3166 - val_accuracy: 0.1000
# Epoch 92/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.1889 - accuracy: 0.9737 - val_loss: 2.2327 - val_accuracy: 0.1000
# Epoch 93/100
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1880 - accuracy: 0.9737 - val_loss: 2.1849 - val_accuracy: 0.1000
# Epoch 94/100
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1885 - accuracy: 0.9474 - val_loss: 2.2165 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1869 - accuracy: 0.9474 - val_loss: 2.2998 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.1827 - accuracy: 0.9474 - val_loss: 2.3665 - val_accuracy: 0.1000
# Epoch 97/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1784 - accuracy: 0.9474 - val_loss: 2.4251 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 2/2 [==============================] - 0s 93ms/step - loss: 0.1734 - accuracy: 0.9737 - val_loss: 2.4677 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1678 - accuracy: 0.9737 - val_loss: 2.5078 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1642 - accuracy: 0.9737 - val_loss: 2.5553 - val_accuracy: 0.0000e+00
# 2/2 [==============================] - 0s 8ms/step
# /Users/apple/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Note: This is just a sample, replace it with your actual dataset
college_exam_data = {
    'Computer Science and Engineering (including specializations) / Information Technology': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'IIT Kharagpur', 'Bits Pilani'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']
    },
    'Electronics and Communication Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'Bits Pilani', 'NIT Trichy'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']
    },
    'Mechanical Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Roorky', 'IIT Guwahati', 'BITS Hyderabad'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']

    },
    'Civil Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'IIT Kanpur', 'IIT BHU'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']

    }
}

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering', '1']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic[0])
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1[0])
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2[0])
print("Predicted Labels - Combined AI:", predicted_labels_combined[0])

def get_college_exam_info(predicted_label):
    return college_exam_data.get(predicted_label, {'colleges': [], 'exams': []})

# Usage:
predicted_label_combined = predicted_labels_combined[0]  # Assuming it's a single prediction
info = get_college_exam_info(predicted_label_combined)

print(f"Prediction: {predicted_label_combined}")
print("Colleges:")
for college in info['colleges']:
    print(f"  - {college}")
print("Entrance Exams:")
for exam in info['exams']:
    print(f"  - {exam}")
print("Resources:")
for res in info['resources']:
    print(f"  - {res}")
# Out:
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 101ms/step
# Predicted Labels - Generic AI: Engineering
# Predicted Labels - Parallel AI 1: Electronics and Communication Engineering
# Predicted Labels - Parallel AI 2: Computer Science and Engineering (including specializations) / Information Technology
# Predicted Labels - Combined AI: Computer Science and Engineering (including specializations) / Information Technology
# Prediction: Computer Science and Engineering (including specializations) / Information Technology
# Colleges:
#   - IIT Madras
#   - IIT Delhi
#   - IIT Bombay
#   - IIT Kharagpur
#   - Bits Pilani
# Entrance Exams:
#   - JEE Mains
#   - JEE Advance
#   - BITSAT
# Resources:
#   - Geeks for Geeks: https://www.geeksforgeeks.org/
#   - CodeChef: https://www.codechef.com/
#   - Coursera: https://www.coursera.org/en-IN
